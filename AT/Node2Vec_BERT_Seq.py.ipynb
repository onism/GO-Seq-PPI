# %%
import numpy as np
import pickle
import keras.backend as K

from keras.layers import  GlobalAveragePooling1D, Input, Activation, MaxPooling1D, BatchNormalization, Dense, Dropout, Conv1D,GlobalMaxPooling1D
from keras.layers import GRU,AveragePooling1D,CuDNNGRU
from keras.layers.merge import Concatenate
from keras.models import Model 
from keras.callbacks import EarlyStopping,ModelCheckpoint
from gensim.models import Word2Vec 

import keras.backend.tensorflow_backend as KTF
import tensorflow as tf
import os


os.environ["CUDA_VISIBLE_DEVICES"] = "0"

config = tf.ConfigProto()
config.gpu_options.allow_growth=True   #不全部占满显存, 按需分配
sess = tf.Session(config=config)

KTF.set_session(sess)
# Out:
# Using TensorFlow backend.
# /home/xhh/anaconda3/envs/py36/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/xhh/anaconda3/envs/py36/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/xhh/anaconda3/envs/py36/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/xhh/anaconda3/envs/py36/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/xhh/anaconda3/envs/py36/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/xhh/anaconda3/envs/py36/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
class TermVectors:
    def __init__(self):
        self.termVectorDict=dict()
        self.terms=None
        self.vectors=None

    def parse_term_embedding_file(self,file_path):
        with open(file_path) as f:
            lines=f.readlines()
            self.vectors=lines[1:] # 第一个是term的数量，不是termID
            terms = []
            for line in lines[1:]:
                term=line.split()[0]
                terms.append(term)
            self.terms = terms

    def str_to_vector(self,Str):
        Str = Str.strip('\n')
        nums = Str.split()
        vec = []
        for num in nums:
            vec.append(float(num))
        return np.array(vec)

    def construct_term_vector_dict(self):
        for term in self.terms:
            termindex = self.terms.index(term)
            line=self.vectors[termindex]
            s =line[len(term):].lstrip(' ')
            s_vec =self.str_to_vector(s)
            self.termVectorDict[term]=s_vec

# %%
# construct Node2Vec termVector
BP_TERM_EMB_FILE_PATH = '../Node2Vec/EDGELIST/BP.emb'
CC_TERM_EMB_FILE_PATH = '../Node2Vec/EDGELIST/CC.emb'
MF_TERM_EMB_FILE_PATH = '../Node2Vec/EDGELIST/MF.emb'
Node2Vec_dim = 300


BPTermVectors = TermVectors()
BPTermVectors.parse_term_embedding_file(BP_TERM_EMB_FILE_PATH)
BPTermVectors.construct_term_vector_dict()
print(len(BPTermVectors.termVectorDict))

CCTermVectors = TermVectors()
CCTermVectors.parse_term_embedding_file(CC_TERM_EMB_FILE_PATH)
CCTermVectors.construct_term_vector_dict()
print(len(CCTermVectors.termVectorDict))

MFTermVectors = TermVectors()
MFTermVectors.parse_term_embedding_file(MF_TERM_EMB_FILE_PATH)
MFTermVectors.construct_term_vector_dict()
print(len(MFTermVectors.termVectorDict))
# Out:
# 29699
# 4202
# 11148

# %%
# read go.obo obtain ontology type
id_type_dicts = {}
obo_file = '../cross-species/go.obo'
fp=open(obo_file,'r')
obo_txt=fp.read()
fp.close()
obo_txt=obo_txt[obo_txt.find("[Term]")-1:]
obo_txt=obo_txt[:obo_txt.find("[Typedef]")]
# obo_dict=parse_obo_txt(obo_txt)
id_type_dicts = {}
for Term_txt in obo_txt.split("[Term]\n"):
    if not Term_txt.strip():
        continue
    name = ''
    ids = []
    for line in Term_txt.splitlines():
        if   line.startswith("id: "):
            ids.append(line[len("id: "):])     
        elif line.startswith("namespace: "):
             name=line[len("namespace: "):]
        elif line.startswith("alt_id: "):
            ids.append(line[len("alt_id: "):])
    
    for t_id in ids:
        id_type_dicts[t_id] = name

# %%
import numpy as np
alphabet = np.array(['A', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'K', 'L',
                     'M', 'N', 'P', 'Q', 'R', 'S', 'T', 'V', 'W', 'Y'])

def label_sequence(line, MAX_SEQ_LEN, smi_ch_ind):
	X = np.zeros(MAX_SEQ_LEN)

	for i, ch in enumerate(line[:MAX_SEQ_LEN]):
		X[i] = smi_ch_ind[ch]

	return X #.tolist()

def letter_one_hot(aa):
    one_hot = np.zeros(20)
    for idx, letter in enumerate(alphabet):
        if aa == letter:
            one_hot[idx] = 1
            return one_hot


# Convert an entire protein to one-hot representation.
def protein_one_hot(protein_sequence, MAX_SEQ_LEN):
    #  Remove non-specific AA codes (very few are actually present in this dataset)
    protein_sequence = protein_sequence.replace('B', '')
    protein_sequence = protein_sequence.replace('J', '')
    protein_sequence = protein_sequence.replace('O', '')
    protein_sequence = protein_sequence.replace('U', '')
    protein_sequence = protein_sequence.replace('X', '')
    protein_sequence = protein_sequence.replace('Z', '')
    one_hot_seq = np.zeros( (MAX_SEQ_LEN, 20))
    for idx, aa in enumerate(protein_sequence[:MAX_SEQ_LEN]):
        one_hot_seq[idx, :] = letter_one_hot(aa)
    return one_hot_seq

# %%
import keras
feature_len = 768
max_go_len = 256
max_seq_len = 1000
max_node_len = 128
from six.moves import cPickle as pickle #for performance

 
def save_dict(di_, filename_):
    with open(filename_, 'wb') as f:
        pickle.dump(di_, f)

def load_dict(filename_):
    with open(filename_, 'rb') as f:
        ret_di = pickle.load(f)
    return ret_di



protein2go = load_dict('ATprot2go.pkl')
prot2nodevec = {}
for key, value in protein2go.items():
    X_go1 =  np.zeros((1,Node2Vec_dim))
    allgos = value.split(',') 
    allgos = list(set(allgos))
    count = 0
    for  go in  allgos:
        if go.startswith('GO'):
            if id_type_dicts[go] == 'biological_process':
                termVectors = BPTermVectors
                term_ID=go[3:].lstrip('0')
                if term_ID in termVectors.termVectorDict.keys():
                    feature = termVectors.termVectorDict[term_ID].reshape(1, Node2Vec_dim)
                else:
                    feature = np.zeros((1,Node2Vec_dim))
                
            elif id_type_dicts[go] == 'cellular_component':
                termVectors = CCTermVectors
                term_ID=go[3:].lstrip('0')
                if term_ID in termVectors.termVectorDict.keys():
                    feature = termVectors.termVectorDict[term_ID].reshape(1, Node2Vec_dim)
                else:
                    feature = np.zeros((1,Node2Vec_dim))
            elif id_type_dicts[go] == 'molecular_function':
                termVectors = MFTermVectors
                term_ID=go[3:].lstrip('0')
                if term_ID in termVectors.termVectorDict.keys():
                    feature = termVectors.termVectorDict[term_ID].reshape(1, Node2Vec_dim)
                else:
                    feature = np.zeros((1,Node2Vec_dim))
            else:
                 feature = np.zeros((1,Node2Vec_dim))


            if count + feature.shape[0] > max_node_len:
                break
            X_go1 = np.concatenate((X_go1,feature ))    
            count += feature.shape[0]
    prot2nodevec[key] =  X_go1[1:]

# %%
prot2emb = {}
for key, value in protein2go.items():
    X_go1 =  np.zeros((1,768))
    allgos = value.split(',') 
    allgos = list(set(allgos))
    count = 0
    for  go in  allgos:
        if go.startswith('GO'):
            feature = np.load('../ncbi_allfeatures4go/'+go+'_0.npy')[1:-1]
            if count + feature.shape[0] > max_go_len:
                break
            X_go1 = np.concatenate((X_go1,feature ))    
            count += feature.shape[0]
    prot2emb[key] =  X_go1[1:]   


class DataGenerator(keras.utils.Sequence):
    'Generates data for Keras'
    def __init__(self,  ppi_pair_file, batch_size=128):
        'Initialization' 
        self.batch_size = batch_size
        self.ppi_pair_file = ppi_pair_file
         
        self.max_seqlen = max_seq_len
        self.max_golen = max_go_len
        self.max_node_len = max_node_len
        self.protein2go =  load_dict('ATprot2go.pkl')
        self.protein2seq = load_dict('ATprot2seq.pkl')
        self.read_ppi()
        self.prot2emb =  prot2emb
#         self.prot2embedding()
        self.protein2onehot = {}
        self.onehot_seqs()
        self.prot2nodevec = prot2nodevec
#         self.prot2nodevec_fun()
        self.on_epoch_end()
    
#     def prot2nodevec_fun(self):
#         for key, value in self.protein2go.items():
#             X_go1 =  np.zeros((1,Node2Vec_dim))
#             allgos = value.split(',') 
#             allgos = list(set(allgos))
#             count = 0
#             for  go in  allgos:
#                 if go.startswith('GO'):
#                     if id_type_dicts[go] == '':
#                         termVectors = BPTermVectors
#                         term_ID=go[3:].lstrip('0')
#                         feature = termVectors.termVectorDict[term_ID]
#                     elif id_type_dicts[go] == '':
#                         termVectors = CCTermVectors
#                         term_ID=go[3:].lstrip('0')
#                         feature = termVectors.termVectorDict[term_ID]
#                     elif id_type_dicts[go] == '':
#                         termVectors = MFTermVectors
#                         term_ID=go[3:].lstrip('0')
#                         feature = termVectors.termVectorDict[term_ID]
#                     else:
#                         feature = np.zeros((1,Node2Vec_dim))
                    
                     
#                     if count + feature.shape[0] > max_go_len:
#                         break
#                     X_go1 = np.concatenate((X_go1,feature ))    
#                     count += feature.shape[0]
#             self.prot2nodevec[key] =  X_go1[1:]   
        
    
    def read_ppi(self):
        with open(self.ppi_pair_file, 'r') as f:
            self.ppi_pairs  =  f.readlines()
            
    
    def onehot_seqs(self):
        for key, value in self.protein2seq.items():
            self.protein2onehot[key] =  protein_one_hot(value, self.max_seqlen) 

    

    def __len__(self):
        'Denotes the number of batches per epoch'
        return int(np.floor(len(self.ppi_pairs) / self.batch_size))

    def __getitem__(self, index):
        'Generate one batch of data'
        # Generate indexes of the batch
        indexes = self.indexes[index*self.batch_size:(index+1)*self.batch_size]
        # Generate data
        X, y = self.__data_generation(indexes)

        return X, y

    
#     def prot2embedding(self):
#         for key, value in self.protein2go.items():
#             X_go1 =  np.zeros((1,768))
#             allgos = value.split(',') 
#             allgos = list(set(allgos))
#             count = 0
#             for  go in  allgos:
#                 if go.startswith('GO'):
#                     feature = np.load('../ncbi_allfeatures4go/'+go+'_0.npy')[1:-1]
#                     if count + feature.shape[0] > max_go_len:
#                         break
#                     X_go1 = np.concatenate((X_go1,feature ))    
#                     count += feature.shape[0]
#             self.prot2emb[key] =  X_go1[1:]   
            
    
    def on_epoch_end(self):
        'Updates indexes after each epoch'
        self.indexes = np.arange(len(self.ppi_pairs))
         
    def __data_generation(self, list_IDs_temp):
        'Generates data containing batch_size samples' # X : (n_samples, *dim, n_channels)
        # Initialization

        X_go1 = np.empty((self.batch_size, self.max_golen,768))
        X_go2 = np.empty((self.batch_size, self.max_golen,768))
        y = np.empty((self.batch_size))
        X_seq1 = np.empty((self.batch_size, self.max_seqlen,20))
        X_seq2 = np.empty((self.batch_size, self.max_seqlen,20))
        
        
        X_node1 = np.empty((self.batch_size, self.max_node_len,Node2Vec_dim))
        X_node2 = np.empty((self.batch_size, self.max_node_len,Node2Vec_dim))

        # Generate data
        for i, ID in enumerate(list_IDs_temp):
            ppi_pair = self.ppi_pairs[ID]
            p1, p2, label = ppi_pair.rstrip().split('\t')
            if label == '+':
                y[i] = 1
            else:
                y[i] = 0
                
            prot1emb = self.prot2emb[p1]
            X_go1[i,:prot1emb.shape[0]] = prot1emb
            
            prot2emb = self.prot2emb[p2]
            X_go2[i,:prot2emb.shape[0]] = prot2emb
            
            X_seq1[i] =  self.protein2onehot[p1]
            X_seq2[i] =  self.protein2onehot[p2]
            
            prot1emb_node = self.prot2nodevec[p1]
            X_node1[i,:prot1emb_node.shape[0]] = prot1emb_node
            
            prot2emb_node = self.prot2nodevec[p2]
            X_node2[i,:prot2emb_node.shape[0]] = prot2emb_node
            
            
            
     
        return [X_go1,X_go2,  X_node1, X_node2, X_seq1, X_seq2] ,  y



    def all_data(self, list_IDs_temp):
        'Generates data containing batch_size samples' # X : (n_samples, *dim, n_channels)
        # Initialization

        X_go1 = np.empty((len(list_IDs_temp), self.max_golen,768))
         
        X_go2 = np.empty((len(list_IDs_temp), self.max_golen,768))
        y = np.empty((len(list_IDs_temp)))
        
        X_seq1 = np.empty((len(list_IDs_temp), self.max_seqlen,20))
        X_seq2 = np.empty((len(list_IDs_temp), self.max_seqlen,20))
        
        
        X_node1 = np.empty((len(list_IDs_temp), self.max_node_len,Node2Vec_dim))
        X_node2 = np.empty((len(list_IDs_temp), self.max_node_len,Node2Vec_dim))

        # Generate data
        for i, ID in enumerate(list_IDs_temp):
            ppi_pair = self.ppi_pairs[ID]
            p1, p2, label = ppi_pair.rstrip().split('\t')
            if label == '+':
                y[i] = 1
            else:
                y[i] = 0
            
            prot1emb = self.prot2emb[p1]
            X_go1[i,:prot1emb.shape[0]] = prot1emb
            
            prot2emb = self.prot2emb[p2]
            X_go2[i,:prot2emb.shape[0]] = prot2emb
            
            X_seq1[i] =  self.protein2onehot[p1]
            X_seq2[i] =  self.protein2onehot[p2]
            
            prot1emb_node = self.prot2nodevec[p1]
            X_node1[i,:prot1emb_node.shape[0]] = prot1emb_node
            
            prot2emb_node = self.prot2nodevec[p2]
            X_node2[i,:prot2emb_node.shape[0]] = prot2emb_node
            
  
        return [X_go1,X_go2, X_node1, X_node2, X_seq1, X_seq2] ,  y

# %%
from keras import backend as K, initializers, regularizers, constraints
from keras.engine.topology import Layer


def dot_product(x, kernel):
    """
    Wrapper for dot product operation, in order to be compatible with both
    Theano and Tensorflow
    Args:
        x (): input
        kernel (): weights
    Returns:
    """
    if K.backend() == 'tensorflow':
        # todo: check that this is correct
        return K.squeeze(K.dot(x, K.expand_dims(kernel)), axis=-1)
    else:
        return K.dot(x, kernel)


class Attention(Layer):
    def __init__(self,
                 W_regularizer=None, b_regularizer=None,
                 W_constraint=None, b_constraint=None,
                 bias=True,
                 return_attention=False,
                 **kwargs):
        """
        Keras Layer that implements an Attention mechanism for temporal data.
        Supports Masking.
        Follows the work of Raffel et al. [https://arxiv.org/abs/1512.08756]
        # Input shape
            3D tensor with shape: `(samples, steps, features)`.
        # Output shape
            2D tensor with shape: `(samples, features)`.
        :param kwargs:
        Just put it on top of an RNN Layer (GRU/LSTM/SimpleRNN) with return_sequences=True.
        The dimensions are inferred based on the output shape of the RNN.
        Note: The layer has been tested with Keras 1.x
        Example:
            # 1
            model.add(LSTM(64, return_sequences=True))
            model.add(Attention())
            # next add a Dense layer (for classification/regression) or whatever...
            # 2 - Get the attention scores
            hidden = LSTM(64, return_sequences=True)(words)
            sentence, word_scores = Attention(return_attention=True)(hidden)
        """
        self.supports_masking = True
        self.return_attention = return_attention
        self.init = initializers.get('glorot_uniform')

        self.W_regularizer = regularizers.get(W_regularizer)
        self.b_regularizer = regularizers.get(b_regularizer)

        self.W_constraint = constraints.get(W_constraint)
        self.b_constraint = constraints.get(b_constraint)

        self.bias = bias
        super(Attention, self).__init__(**kwargs)

    def build(self, input_shape):
        assert len(input_shape) == 3

        self.W = self.add_weight((input_shape[-1],),
                                 initializer=self.init,
                                 name='{}_W'.format(self.name),
                                 regularizer=self.W_regularizer,
                                 constraint=self.W_constraint)
        if self.bias:
            self.b = self.add_weight((input_shape[1],),
                                     initializer='zero',
                                     name='{}_b'.format(self.name),
                                     regularizer=self.b_regularizer,
                                     constraint=self.b_constraint)
        else:
            self.b = None

        self.built = True

    def compute_mask(self, input, input_mask=None):
        # do not pass the mask to the next layers
        return None

    def call(self, x, mask=None):
        eij = dot_product(x, self.W)

        if self.bias:
            eij += self.b

        eij = K.tanh(eij)

        a = K.exp(eij)

        # apply mask after the exp. will be re-normalized next
        if mask is not None:
            # Cast the mask to floatX to avoid float64 upcasting in theano
            a *= K.cast(mask, K.floatx())

        # in some cases especially in the early stages of training the sum may be almost zero
        # and this results in NaN's. A workaround is to add a very small positive number ε to the sum.
        # a /= K.cast(K.sum(a, axis=1, keepdims=True), K.floatx())
        a /= K.cast(K.sum(a, axis=1, keepdims=True) + K.epsilon(), K.floatx())

        weighted_input = x * K.expand_dims(a)

        result = K.sum(weighted_input, axis=1)

        if self.return_attention:
            return [result, a]
        return result

    def compute_output_shape(self, input_shape):
        if self.return_attention:
            return [(input_shape[0], input_shape[-1]),
                    (input_shape[0], input_shape[1])]
        else:
            return input_shape[0], input_shape[-1]

# %%
from keras.layers import   Embedding
from keras.layers import  GRU, Bidirectional, CuDNNGRU, Lambda, dot, Flatten, CuDNNLSTM, Add
from keras.layers.merge import concatenate

def inception_block(input_tensor, output_size):
    """"""
    con1d_filters = int(output_size/4)
    y = Conv1D(con1d_filters, 3, activation="relu", padding='same')(input_tensor)
    x1 = Conv1D(con1d_filters, 5, activation="relu", padding='same')(y)

    y = Conv1D(con1d_filters, 1, activation="relu", padding='valid')(input_tensor)
    x2 = Conv1D(con1d_filters, 3, activation="relu", padding='same')(y)

    x3 = Conv1D(con1d_filters, 3, activation="relu", padding='same')(input_tensor)
    x4 = Conv1D(con1d_filters, 1, activation="relu", padding='same')(input_tensor)

    y = Concatenate()([x1, x2, x3, x4])
#     y = MaxPooling1D(2)(y)
    # y = AveragePooling1D()(mix0)
#     y = BatchNormalization()(y)

    return y


 
def build_cnn_gru_model(input_x, con_filters, gru_units):
    x = inception_block(input_x,con_filters )
    x = Dropout(0.3)(x)
    x_gru = Bidirectional(CuDNNGRU(gru_units, return_sequences=True))(x)
    x_gru = Dropout(0.3)(x_gru)
     
    x_a = GlobalAveragePooling1D()(x)
    x_b = GlobalMaxPooling1D()(x)
    x_c = Attention()(x)
    x_gru_a = GlobalAveragePooling1D()(x_gru)
    x_gru_b = GlobalMaxPooling1D()(x_gru)
    x_gru_c = Attention()(x_gru)
    x = Concatenate()([ x_a, x_b, x_c,  x_gru_a, x_gru_b,   x_gru_c])
    x = Dense(256)(x)
    return x


def build_cnn_model(input_x, con_filters, gru_units):
    x = inception_block(input_x,con_filters )
    x = Dropout(0.3)(x)
    
     
    x_a = GlobalAveragePooling1D()(x)
    x_b = GlobalMaxPooling1D()(x)
    x_c = Attention()(x)
    
    x = Concatenate()([ x_a, x_b, x_c])
    x = Dense(256)(x)
    return x 


def build_model():
    con_filters = 128
    gru_units = 64
    left_input_go = Input(shape=(max_go_len,feature_len))
    right_input_go = Input(shape=(max_go_len,feature_len))
    
    left_input_node = Input(shape=(max_node_len,Node2Vec_dim))
    right_input_node = Input(shape=(max_node_len,Node2Vec_dim))
    
    
    left_input_seq = Input(shape=(max_seq_len,20))
    right_input_seq = Input(shape=(max_seq_len,20))
    

    left_x_go = build_cnn_gru_model(left_input_go, con_filters, gru_units)
    right_x_go = build_cnn_gru_model(right_input_go, con_filters,gru_units)
    
    left_x_seq = build_cnn_gru_model(left_input_seq, con_filters, gru_units)
    right_x_seq = build_cnn_gru_model(right_input_seq, con_filters, gru_units)
    
    left_x_node = build_cnn_gru_model(left_input_node, con_filters, gru_units)
    right_x_node = build_cnn_gru_model(right_input_node, con_filters,gru_units)
    
   
    
   
   
    x =   Concatenate()([left_x_go  , right_x_go, left_x_node,  right_x_node, left_x_seq, right_x_seq])
    x = Dense(1024, activation='relu')(x)
    x = Dropout(0.1)(x)
    x = Dense(1024, activation='relu')(x)
    x = Dropout(0.1)(x)
    x = Dense(512, activation='relu')(x)
  
    x = Dense(1)(x)
    output = Activation('sigmoid')(x)
    # model = Model([left_input_go, right_input_go], output)
  
    model = Model([left_input_go, right_input_go, left_input_node, right_input_node,     left_input_seq, right_input_seq], output)
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model


 

model = build_model()
model.summary()
# siamese_a = create_share_model()
# siamese_a.summary()
# Out:
# WARNING:tensorflow:From /home/xhh/anaconda3/envs/py36/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /home/xhh/anaconda3/envs/py36/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /home/xhh/anaconda3/envs/py36/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /home/xhh/anaconda3/envs/py36/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /home/xhh/anaconda3/envs/py36/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /home/xhh/anaconda3/envs/py36/lib/python3.6/site-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /home/xhh/anaconda3/envs/py36/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3657: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /home/xhh/anaconda3/envs/py36/lib/python3.6/site-packages/tensorflow/python/ops/nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 256, 768)     0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, 256, 768)     0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            (None, 128, 300)     0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            (None, 128, 300)     0
# __________________________________________________________________________________________________
# input_5 (InputLayer)            (None, 1000, 20)     0
# __________________________________________________________________________________________________
# input_6 (InputLayer)            (None, 1000, 20)     0
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 256, 32)      73760       input_1[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 256, 32)      24608       input_1[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 256, 32)      73760       input_2[0][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 256, 32)      24608       input_2[0][0]
# __________________________________________________________________________________________________
# conv1d_25 (Conv1D)              (None, 128, 32)      28832       input_3[0][0]
# __________________________________________________________________________________________________
# conv1d_27 (Conv1D)              (None, 128, 32)      9632        input_3[0][0]
# __________________________________________________________________________________________________
# conv1d_31 (Conv1D)              (None, 128, 32)      28832       input_4[0][0]
# __________________________________________________________________________________________________
# conv1d_33 (Conv1D)              (None, 128, 32)      9632        input_4[0][0]
# __________________________________________________________________________________________________
# conv1d_13 (Conv1D)              (None, 1000, 32)     1952        input_5[0][0]
# __________________________________________________________________________________________________
# conv1d_15 (Conv1D)              (None, 1000, 32)     672         input_5[0][0]
# __________________________________________________________________________________________________
# conv1d_19 (Conv1D)              (None, 1000, 32)     1952        input_6[0][0]
# __________________________________________________________________________________________________
# conv1d_21 (Conv1D)              (None, 1000, 32)     672         input_6[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 256, 32)      5152        conv1d_1[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 256, 32)      3104        conv1d_3[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 256, 32)      73760       input_1[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 256, 32)      24608       input_1[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 256, 32)      5152        conv1d_7[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 256, 32)      3104        conv1d_9[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 256, 32)      73760       input_2[0][0]
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 256, 32)      24608       input_2[0][0]
# __________________________________________________________________________________________________
# conv1d_26 (Conv1D)              (None, 128, 32)      5152        conv1d_25[0][0]
# __________________________________________________________________________________________________
# conv1d_28 (Conv1D)              (None, 128, 32)      3104        conv1d_27[0][0]
# __________________________________________________________________________________________________
# conv1d_29 (Conv1D)              (None, 128, 32)      28832       input_3[0][0]
# __________________________________________________________________________________________________
# conv1d_30 (Conv1D)              (None, 128, 32)      9632        input_3[0][0]
# __________________________________________________________________________________________________
# conv1d_32 (Conv1D)              (None, 128, 32)      5152        conv1d_31[0][0]
# __________________________________________________________________________________________________
# conv1d_34 (Conv1D)              (None, 128, 32)      3104        conv1d_33[0][0]
# __________________________________________________________________________________________________
# conv1d_35 (Conv1D)              (None, 128, 32)      28832       input_4[0][0]
# __________________________________________________________________________________________________
# conv1d_36 (Conv1D)              (None, 128, 32)      9632        input_4[0][0]
# __________________________________________________________________________________________________
# conv1d_14 (Conv1D)              (None, 1000, 32)     5152        conv1d_13[0][0]
# __________________________________________________________________________________________________
# conv1d_16 (Conv1D)              (None, 1000, 32)     3104        conv1d_15[0][0]
# __________________________________________________________________________________________________
# conv1d_17 (Conv1D)              (None, 1000, 32)     1952        input_5[0][0]
# __________________________________________________________________________________________________
# conv1d_18 (Conv1D)              (None, 1000, 32)     672         input_5[0][0]
# __________________________________________________________________________________________________
# conv1d_20 (Conv1D)              (None, 1000, 32)     5152        conv1d_19[0][0]
# __________________________________________________________________________________________________
# conv1d_22 (Conv1D)              (None, 1000, 32)     3104        conv1d_21[0][0]
# __________________________________________________________________________________________________
# conv1d_23 (Conv1D)              (None, 1000, 32)     1952        input_6[0][0]
# __________________________________________________________________________________________________
# conv1d_24 (Conv1D)              (None, 1000, 32)     672         input_6[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 256, 128)     0           conv1d_2[0][0]
#                                                                  conv1d_4[0][0]
#                                                                  conv1d_5[0][0]
#                                                                  conv1d_6[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 256, 128)     0           conv1d_8[0][0]
#                                                                  conv1d_10[0][0]
#                                                                  conv1d_11[0][0]
#                                                                  conv1d_12[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 128, 128)     0           conv1d_26[0][0]
#                                                                  conv1d_28[0][0]
#                                                                  conv1d_29[0][0]
#                                                                  conv1d_30[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 128, 128)     0           conv1d_32[0][0]
#                                                                  conv1d_34[0][0]
#                                                                  conv1d_35[0][0]
#                                                                  conv1d_36[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 1000, 128)    0           conv1d_14[0][0]
#                                                                  conv1d_16[0][0]
#                                                                  conv1d_17[0][0]
#                                                                  conv1d_18[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 1000, 128)    0           conv1d_20[0][0]
#                                                                  conv1d_22[0][0]
#                                                                  conv1d_23[0][0]
#                                                                  conv1d_24[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 256, 128)     0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 256, 128)     0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 128, 128)     0           concatenate_9[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 128, 128)     0           concatenate_11[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 1000, 128)    0           concatenate_5[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 1000, 128)    0           concatenate_7[0][0]
# __________________________________________________________________________________________________
# bidirectional_1 (Bidirectional) (None, 256, 128)     74496       dropout_1[0][0]
# __________________________________________________________________________________________________
# bidirectional_2 (Bidirectional) (None, 256, 128)     74496       dropout_3[0][0]
# __________________________________________________________________________________________________
# bidirectional_5 (Bidirectional) (None, 128, 128)     74496       dropout_9[0][0]
# __________________________________________________________________________________________________
# bidirectional_6 (Bidirectional) (None, 128, 128)     74496       dropout_11[0][0]
# __________________________________________________________________________________________________
# bidirectional_3 (Bidirectional) (None, 1000, 128)    74496       dropout_5[0][0]
# __________________________________________________________________________________________________
# bidirectional_4 (Bidirectional) (None, 1000, 128)    74496       dropout_7[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 256, 128)     0           bidirectional_1[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 256, 128)     0           bidirectional_2[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 128, 128)     0           bidirectional_5[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 128, 128)     0           bidirectional_6[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 1000, 128)    0           bidirectional_3[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 1000, 128)    0           bidirectional_4[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_1 (Glo (None, 128)          0           dropout_1[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_1 (GlobalM (None, 128)          0           dropout_1[0][0]
# __________________________________________________________________________________________________
# attention_1 (Attention)         (None, 128)          384         dropout_1[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_2 (Glo (None, 128)          0           dropout_2[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_2 (GlobalM (None, 128)          0           dropout_2[0][0]
# __________________________________________________________________________________________________
# attention_2 (Attention)         (None, 128)          384         dropout_2[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_3 (Glo (None, 128)          0           dropout_3[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_3 (GlobalM (None, 128)          0           dropout_3[0][0]
# __________________________________________________________________________________________________
# attention_3 (Attention)         (None, 128)          384         dropout_3[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_4 (Glo (None, 128)          0           dropout_4[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_4 (GlobalM (None, 128)          0           dropout_4[0][0]
# __________________________________________________________________________________________________
# attention_4 (Attention)         (None, 128)          384         dropout_4[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_9 (Glo (None, 128)          0           dropout_9[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_9 (GlobalM (None, 128)          0           dropout_9[0][0]
# __________________________________________________________________________________________________
# attention_9 (Attention)         (None, 128)          256         dropout_9[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_10 (Gl (None, 128)          0           dropout_10[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_10 (Global (None, 128)          0           dropout_10[0][0]
# __________________________________________________________________________________________________
# attention_10 (Attention)        (None, 128)          256         dropout_10[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_11 (Gl (None, 128)          0           dropout_11[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_11 (Global (None, 128)          0           dropout_11[0][0]
# __________________________________________________________________________________________________
# attention_11 (Attention)        (None, 128)          256         dropout_11[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_12 (Gl (None, 128)          0           dropout_12[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_12 (Global (None, 128)          0           dropout_12[0][0]
# __________________________________________________________________________________________________
# attention_12 (Attention)        (None, 128)          256         dropout_12[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_5 (Glo (None, 128)          0           dropout_5[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_5 (GlobalM (None, 128)          0           dropout_5[0][0]
# __________________________________________________________________________________________________
# attention_5 (Attention)         (None, 128)          1128        dropout_5[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_6 (Glo (None, 128)          0           dropout_6[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_6 (GlobalM (None, 128)          0           dropout_6[0][0]
# __________________________________________________________________________________________________
# attention_6 (Attention)         (None, 128)          1128        dropout_6[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_7 (Glo (None, 128)          0           dropout_7[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_7 (GlobalM (None, 128)          0           dropout_7[0][0]
# __________________________________________________________________________________________________
# attention_7 (Attention)         (None, 128)          1128        dropout_7[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_8 (Glo (None, 128)          0           dropout_8[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_8 (GlobalM (None, 128)          0           dropout_8[0][0]
# __________________________________________________________________________________________________
# attention_8 (Attention)         (None, 128)          1128        dropout_8[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 768)          0           global_average_pooling1d_1[0][0]
#                                                                  global_max_pooling1d_1[0][0]
#                                                                  attention_1[0][0]
#                                                                  global_average_pooling1d_2[0][0]
#                                                                  global_max_pooling1d_2[0][0]
#                                                                  attention_2[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 768)          0           global_average_pooling1d_3[0][0]
#                                                                  global_max_pooling1d_3[0][0]
#                                                                  attention_3[0][0]
#                                                                  global_average_pooling1d_4[0][0]
#                                                                  global_max_pooling1d_4[0][0]
#                                                                  attention_4[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 768)          0           global_average_pooling1d_9[0][0]
#                                                                  global_max_pooling1d_9[0][0]
#                                                                  attention_9[0][0]
#                                                                  global_average_pooling1d_10[0][0]
#                                                                  global_max_pooling1d_10[0][0]
#                                                                  attention_10[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 768)          0           global_average_pooling1d_11[0][0]
#                                                                  global_max_pooling1d_11[0][0]
#                                                                  attention_11[0][0]
#                                                                  global_average_pooling1d_12[0][0]
#                                                                  global_max_pooling1d_12[0][0]
#                                                                  attention_12[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 768)          0           global_average_pooling1d_5[0][0]
#                                                                  global_max_pooling1d_5[0][0]
#                                                                  attention_5[0][0]
#                                                                  global_average_pooling1d_6[0][0]
#                                                                  global_max_pooling1d_6[0][0]
#                                                                  attention_6[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 768)          0           global_average_pooling1d_7[0][0]
#                                                                  global_max_pooling1d_7[0][0]
#                                                                  attention_7[0][0]
#                                                                  global_average_pooling1d_8[0][0]
#                                                                  global_max_pooling1d_8[0][0]
#                                                                  attention_8[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 256)          196864      concatenate_2[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 256)          196864      concatenate_4[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 256)          196864      concatenate_10[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 256)          196864      concatenate_12[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 256)          196864      concatenate_6[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 256)          196864      concatenate_8[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 1536)         0           dense_1[0][0]
#                                                                  dense_2[0][0]
#                                                                  dense_5[0][0]
#                                                                  dense_6[0][0]
#                                                                  dense_3[0][0]
#                                                                  dense_4[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 1024)         1573888     concatenate_13[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 1024)         0           dense_7[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 1024)         1049600     dropout_13[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 1024)         0           dense_8[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 512)          524800      dropout_14[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 1)            513         dense_9[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 1)            0           dense_10[0][0]
# ==================================================================================================
# Total params: 5,391,393
# Trainable params: 5,391,393
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from sklearn.model_selection import StratifiedKFold
from keras.models import load_model
from sklearn.metrics import accuracy_score
from sklearn.metrics import matthews_corrcoef
from sklearn.metrics import confusion_matrix
from sklearn import metrics
from sklearn.metrics import f1_score
from sklearn.metrics import precision_score
dataset_name = 'SC'
for rep in range(2,3):
    n_splits = 10
    TPRs =  np.zeros(n_splits)
    FPRs = np.zeros(n_splits)
    Precs = np.zeros(n_splits)
    ACCs = np.zeros(n_splits)
    F1s = np.zeros(n_splits)
    MCCs = np.zeros(n_splits)
    AUCs = np.zeros(n_splits)
    skf = StratifiedKFold(n_splits=n_splits)
    count = 0
    for split in range(n_splits):
        train_pairs_file = 'CV/train'+str(rep)+'-'+str(split)
        test_pairs_file = 'CV/test'+str(rep)+'-'+str(split)
        valid_pairs_file = 'CV/valid'+str(rep)+'-'+str(split)
        
         

        batch_size = 64
        train_generator = DataGenerator(   train_pairs_file,batch_size = batch_size )
        test_generator = DataGenerator(   test_pairs_file,batch_size = batch_size)
        valid_generator = DataGenerator(   valid_pairs_file,batch_size = batch_size)
         
        # model = build_model_without_att()
        model = build_model()
        save_model_name = 'CV/node_go_seq'+str(rep)+'-'+str(split) + '.hdf5'
        
        earlyStopping = EarlyStopping(monitor='val_acc', patience=20, verbose=0, mode='max')
        save_checkpoint = ModelCheckpoint(save_model_name, save_best_only=True,  verbose=1, monitor='val_acc', mode='max', save_weights_only=True)

         
        # validation_data = (valid_X, valid_Y),  verbose=1,callbacks=[earlyStopping, save_checkpoint]
        hist = model.fit_generator(generator=train_generator,
                   epochs = 100,verbose=1,validation_data = valid_generator,
                                 callbacks=[earlyStopping, save_checkpoint] )
         
        
        # model = load_model(save_model_name)
        model.load_weights(save_model_name)
        with open(test_pairs_file, 'r') as f:
            test_ppi_pairs  =  f.readlines()

        test_len = len(test_ppi_pairs) 
        list_IDs_temp = np.arange(test_len)

        test_x, y_test = test_generator.all_data(list_IDs_temp)

        y_pred_prob = model.predict(test_x)

       
        y_pred = (y_pred_prob > 0.5)
        auc = metrics.roc_auc_score(y_test, y_pred_prob) 
        f1 = f1_score(y_test, y_pred)
        pre = precision_score(y_test, y_pred)
        acc = accuracy_score(y_test, y_pred)

        precision, recall, _thresholds = metrics.precision_recall_curve(y_test, y_pred_prob)
        pr_auc = metrics.auc(recall, precision)
        mcc = matthews_corrcoef(y_test, y_pred)

        tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()
        total=tn+fp+fn+tp
        sen = float(tp)/float(tp+fn)
        sps = float(tn)/float((tn+fp))

        tpr = float(tp)/float(tp+fn)
        fpr = float(fp)/float((tn+fp))
        print('--------------------------\n')
        print ('AUC: %f' % auc)
        print ('ACC: %f' % acc) 
        # print("PRAUC: %f" % pr_auc)
        print ('MCC : %f' % mcc)
        # print ('SEN: %f' % sen)
        # print ('SEP: %f' % sps)
        print('TPR:%f'%tpr)
        print('FPR:%f'%fpr)
        print('Pre:%f'%pre)
        print('F1:%f'%f1)
        print('--------------------------\n')
        TPRs[count] = tpr
        FPRs[count] = fpr
        Precs[count] =pre
        ACCs[count] =acc
        F1s[count] =f1
        MCCs[count] =mcc
        AUCs[count] =auc
        count += 1
        del test_x
        del y_test
    print ('mean AUC: %f' % np.mean(AUCs))
    print ('mean ACC: %f' % np.mean(ACCs)) 
    print ('mean MCC : %f' % np.mean(MCCs))
    print('mean TPR:%f'% np.mean(TPRs))
    print('mean FPR:%f'% np.mean(FPRs))
    print('mean Pre:%f'% np.mean(Precs))
    print('mean F1:%f'% np.mean(F1s))
    np.savez('node2vec_go_seq'+str(rep), AUCs=AUCs, ACCs=ACCs, MCCs=MCCs, TPRs = TPRs, FPRs=FPRs, Precs=Precs, F1s=F1s)
# Out:
# Epoch 1/100
# 13/13 [==============================] - 25s 2s/step - loss: 0.9536 - acc: 0.5204 - val_loss: 0.6965 - val_acc: 0.5156
#
# Epoch 00001: val_acc improved from -inf to 0.51562, saving model to CV/node_go_seq2-0.hdf5
# Epoch 2/100
# 13/13 [==============================] - 6s 485ms/step - loss: 0.6275 - acc: 0.6454 - val_loss: 0.6113 - val_acc: 0.6406
#
# Epoch 00002: val_acc improved from 0.51562 to 0.64062, saving model to CV/node_go_seq2-0.hdf5
# Epoch 3/100
# 13/13 [==============================] - 7s 539ms/step - loss: 0.5293 - acc: 0.7356 - val_loss: 0.6213 - val_acc: 0.6719
#
# Epoch 00003: val_acc improved from 0.64062 to 0.67188, saving model to CV/node_go_seq2-0.hdf5
# Epoch 4/100
# 13/13 [==============================] - 6s 500ms/step - loss: 0.4955 - acc: 0.7752 - val_loss: 0.6632 - val_acc: 0.6719
#
# Epoch 00004: val_acc did not improve from 0.67188
# Epoch 5/100
# 13/13 [==============================] - 7s 527ms/step - loss: 0.4555 - acc: 0.7885 - val_loss: 0.6334 - val_acc: 0.7031
#
# Epoch 00005: val_acc improved from 0.67188 to 0.70312, saving model to CV/node_go_seq2-0.hdf5
# Epoch 6/100
# 13/13 [==============================] - 7s 506ms/step - loss: 0.3250 - acc: 0.8738 - val_loss: 0.7331 - val_acc: 0.6406
#
# Epoch 00006: val_acc did not improve from 0.70312
# Epoch 7/100
# 13/13 [==============================] - 6s 459ms/step - loss: 0.2393 - acc: 0.9099 - val_loss: 1.0250 - val_acc: 0.6562
#
# Epoch 00007: val_acc did not improve from 0.70312
# Epoch 8/100
# 13/13 [==============================] - 6s 462ms/step - loss: 0.2165 - acc: 0.9135 - val_loss: 0.8597 - val_acc: 0.6250
#
# Epoch 00008: val_acc did not improve from 0.70312
# Epoch 9/100
# 13/13 [==============================] - 6s 480ms/step - loss: 0.1868 - acc: 0.9279 - val_loss: 0.9522 - val_acc: 0.6094
#
# Epoch 00009: val_acc did not improve from 0.70312
# Epoch 10/100
# 13/13 [==============================] - 6s 464ms/step - loss: 0.2289 - acc: 0.9014 - val_loss: 0.8358 - val_acc: 0.6250
#
# Epoch 00010: val_acc did not improve from 0.70312
# Epoch 11/100
# 13/13 [==============================] - 6s 469ms/step - loss: 0.2130 - acc: 0.9135 - val_loss: 0.7668 - val_acc: 0.6719
#
# Epoch 00011: val_acc did not improve from 0.70312
# Epoch 12/100
# 13/13 [==============================] - 6s 452ms/step - loss: 0.1235 - acc: 0.9507 - val_loss: 1.3510 - val_acc: 0.6250
#
# Epoch 00012: val_acc did not improve from 0.70312
# Epoch 13/100
# 13/13 [==============================] - 6s 449ms/step - loss: 0.0664 - acc: 0.9700 - val_loss: 1.0474 - val_acc: 0.6562
#
# Epoch 00013: val_acc did not improve from 0.70312
# Epoch 14/100
# 13/13 [==============================] - 6s 447ms/step - loss: 0.0753 - acc: 0.9760 - val_loss: 1.3691 - val_acc: 0.6406
#
# Epoch 00014: val_acc did not improve from 0.70312
# Epoch 15/100
# 13/13 [==============================] - 6s 457ms/step - loss: 0.1146 - acc: 0.9627 - val_loss: 1.2848 - val_acc: 0.6406
#
# Epoch 00015: val_acc did not improve from 0.70312
# Epoch 16/100
# 13/13 [==============================] - 6s 445ms/step - loss: 0.1361 - acc: 0.9507 - val_loss: 1.3258 - val_acc: 0.6406
#
# Epoch 00016: val_acc did not improve from 0.70312
# Epoch 17/100
# 13/13 [==============================] - 6s 470ms/step - loss: 0.2644 - acc: 0.9219 - val_loss: 0.6629 - val_acc: 0.7344
#
# Epoch 00017: val_acc improved from 0.70312 to 0.73438, saving model to CV/node_go_seq2-0.hdf5
# Epoch 18/100
# 13/13 [==============================] - 6s 465ms/step - loss: 0.3209 - acc: 0.8666 - val_loss: 1.0347 - val_acc: 0.7500
#
# Epoch 00018: val_acc improved from 0.73438 to 0.75000, saving model to CV/node_go_seq2-0.hdf5
# Epoch 19/100
# 13/13 [==============================] - 6s 456ms/step - loss: 0.1580 - acc: 0.9411 - val_loss: 1.4311 - val_acc: 0.5781
#
# Epoch 00019: val_acc did not improve from 0.75000
# Epoch 20/100
# 13/13 [==============================] - 6s 463ms/step - loss: 0.1260 - acc: 0.9591 - val_loss: 1.3031 - val_acc: 0.6875
#
# Epoch 00020: val_acc did not improve from 0.75000
# Epoch 21/100
# 13/13 [==============================] - 6s 448ms/step - loss: 0.0782 - acc: 0.9784 - val_loss: 1.2719 - val_acc: 0.6250
#
# Epoch 00021: val_acc did not improve from 0.75000
# Epoch 22/100
# 13/13 [==============================] - 6s 448ms/step - loss: 0.0784 - acc: 0.9675 - val_loss: 0.9244 - val_acc: 0.6406
#
# Epoch 00022: val_acc did not improve from 0.75000
# Epoch 23/100
# 13/13 [==============================] - 6s 433ms/step - loss: 0.1049 - acc: 0.9591 - val_loss: 1.7900 - val_acc: 0.7031
#
# Epoch 00023: val_acc did not improve from 0.75000
# Epoch 24/100
# 13/13 [==============================] - 6s 454ms/step - loss: 0.0414 - acc: 0.9880 - val_loss: 1.5903 - val_acc: 0.6875
#
# Epoch 00024: val_acc did not improve from 0.75000
# Epoch 25/100
# 13/13 [==============================] - 6s 435ms/step - loss: 0.1064 - acc: 0.9772 - val_loss: 1.1231 - val_acc: 0.7031
#
# Epoch 00025: val_acc did not improve from 0.75000
# Epoch 26/100
# 13/13 [==============================] - 6s 436ms/step - loss: 0.1026 - acc: 0.9651 - val_loss: 1.7611 - val_acc: 0.6562
#
# Epoch 00026: val_acc did not improve from 0.75000
# Epoch 27/100
# 13/13 [==============================] - 6s 458ms/step - loss: 0.1264 - acc: 0.9555 - val_loss: 1.0318 - val_acc: 0.7188
#
# Epoch 00027: val_acc did not improve from 0.75000
# Epoch 28/100
# 13/13 [==============================] - 6s 458ms/step - loss: 0.0518 - acc: 0.9844 - val_loss: 2.0043 - val_acc: 0.6406
#
# Epoch 00028: val_acc did not improve from 0.75000
# Epoch 29/100
# 13/13 [==============================] - 6s 460ms/step - loss: 0.1707 - acc: 0.9423 - val_loss: 1.1293 - val_acc: 0.7031
#
# Epoch 00029: val_acc did not improve from 0.75000
# Epoch 30/100
# 13/13 [==============================] - 6s 445ms/step - loss: 0.1168 - acc: 0.9675 - val_loss: 0.8776 - val_acc: 0.7031
#
# Epoch 00030: val_acc did not improve from 0.75000
# Epoch 31/100
# 13/13 [==============================] - 6s 445ms/step - loss: 0.0456 - acc: 0.9844 - val_loss: 1.7947 - val_acc: 0.6562
#
# Epoch 00031: val_acc did not improve from 0.75000
# Epoch 32/100
# 13/13 [==============================] - 6s 459ms/step - loss: 0.0901 - acc: 0.9736 - val_loss: 1.3755 - val_acc: 0.6406
#
# Epoch 00032: val_acc did not improve from 0.75000
# Epoch 33/100
# 13/13 [==============================] - 6s 450ms/step - loss: 0.0939 - acc: 0.9700 - val_loss: 1.2169 - val_acc: 0.6250
#
# Epoch 00033: val_acc did not improve from 0.75000
# Epoch 34/100
# 13/13 [==============================] - 6s 456ms/step - loss: 0.0776 - acc: 0.9748 - val_loss: 1.1137 - val_acc: 0.6406
#
# Epoch 00034: val_acc did not improve from 0.75000
# Epoch 35/100
# 13/13 [==============================] - 6s 471ms/step - loss: 0.0366 - acc: 0.9904 - val_loss: 1.3550 - val_acc: 0.7188
#
# Epoch 00035: val_acc did not improve from 0.75000
# Epoch 36/100
# 13/13 [==============================] - 6s 452ms/step - loss: 0.0948 - acc: 0.9736 - val_loss: 0.8660 - val_acc: 0.6875
#
# Epoch 00036: val_acc did not improve from 0.75000
# Epoch 37/100
# 13/13 [==============================] - 6s 469ms/step - loss: 0.0768 - acc: 0.9820 - val_loss: 0.9506 - val_acc: 0.7031
#
# Epoch 00037: val_acc did not improve from 0.75000
# Epoch 38/100
# 13/13 [==============================] - 6s 449ms/step - loss: 0.0387 - acc: 0.9904 - val_loss: 1.2447 - val_acc: 0.6719
#
# Epoch 00038: val_acc did not improve from 0.75000
# --------------------------
#
# AUC: 0.968667
# ACC: 0.909091
# MCC : 0.823380
# TPR:0.866667
# FPR:0.040000
# Pre:0.962963
# F1:0.912281
# --------------------------
#
# Epoch 1/100
# 13/13 [==============================] - 18s 1s/step - loss: 0.9846 - acc: 0.4892 - val_loss: 0.6959 - val_acc: 0.4844
#
# Epoch 00001: val_acc improved from -inf to 0.48438, saving model to CV/node_go_seq2-1.hdf5
# Epoch 2/100
# 13/13 [==============================] - 6s 452ms/step - loss: 0.6982 - acc: 0.5841 - val_loss: 0.6426 - val_acc: 0.5781
#
# Epoch 00002: val_acc improved from 0.48438 to 0.57812, saving model to CV/node_go_seq2-1.hdf5
# Epoch 3/100
# 13/13 [==============================] - 6s 450ms/step - loss: 0.6119 - acc: 0.6803 - val_loss: 0.5528 - val_acc: 0.7188
#
# Epoch 00003: val_acc improved from 0.57812 to 0.71875, saving model to CV/node_go_seq2-1.hdf5
# Epoch 4/100
# 13/13 [==============================] - 6s 442ms/step - loss: 0.5351 - acc: 0.7416 - val_loss: 0.5762 - val_acc: 0.7344
#
# Epoch 00004: val_acc improved from 0.71875 to 0.73438, saving model to CV/node_go_seq2-1.hdf5
# Epoch 5/100
# 13/13 [==============================] - 6s 455ms/step - loss: 0.4637 - acc: 0.7933 - val_loss: 0.5171 - val_acc: 0.7031
#
# Epoch 00005: val_acc did not improve from 0.73438
# Epoch 6/100
# 13/13 [==============================] - 6s 471ms/step - loss: 0.3645 - acc: 0.8353 - val_loss: 0.5076 - val_acc: 0.7969
#
# Epoch 00006: val_acc improved from 0.73438 to 0.79688, saving model to CV/node_go_seq2-1.hdf5
# Epoch 7/100
# 13/13 [==============================] - 6s 484ms/step - loss: 0.2958 - acc: 0.8858 - val_loss: 0.4886 - val_acc: 0.7656
#
# Epoch 00007: val_acc did not improve from 0.79688
# Epoch 8/100
# 13/13 [==============================] - 6s 461ms/step - loss: 0.3052 - acc: 0.8594 - val_loss: 0.5516 - val_acc: 0.7031
#
# Epoch 00008: val_acc did not improve from 0.79688
# Epoch 9/100
# 13/13 [==============================] - 6s 452ms/step - loss: 0.2662 - acc: 0.8798 - val_loss: 1.0047 - val_acc: 0.5938
#
# Epoch 00009: val_acc did not improve from 0.79688
# Epoch 10/100
# 13/13 [==============================] - 6s 469ms/step - loss: 0.2662 - acc: 0.9062 - val_loss: 0.6011 - val_acc: 0.7344
#
# Epoch 00010: val_acc did not improve from 0.79688
# Epoch 11/100
# 13/13 [==============================] - 6s 459ms/step - loss: 0.1278 - acc: 0.9483 - val_loss: 0.8545 - val_acc: 0.7031
#
# Epoch 00011: val_acc did not improve from 0.79688
# Epoch 12/100
# 13/13 [==============================] - 6s 467ms/step - loss: 0.2339 - acc: 0.8990 - val_loss: 0.6831 - val_acc: 0.6562
#
# Epoch 00012: val_acc did not improve from 0.79688
# Epoch 13/100
# 13/13 [==============================] - 6s 445ms/step - loss: 0.1415 - acc: 0.9483 - val_loss: 0.7089 - val_acc: 0.7344
#
# Epoch 00013: val_acc did not improve from 0.79688
# Epoch 14/100
# 13/13 [==============================] - 6s 443ms/step - loss: 0.0955 - acc: 0.9663 - val_loss: 0.6863 - val_acc: 0.7812
#
# Epoch 00014: val_acc did not improve from 0.79688
# Epoch 15/100
# 13/13 [==============================] - 6s 454ms/step - loss: 0.1009 - acc: 0.9639 - val_loss: 0.4987 - val_acc: 0.8281
#
# Epoch 00015: val_acc improved from 0.79688 to 0.82812, saving model to CV/node_go_seq2-1.hdf5
# Epoch 16/100
# 13/13 [==============================] - 6s 449ms/step - loss: 0.2833 - acc: 0.8906 - val_loss: 0.5724 - val_acc: 0.7188
#
# Epoch 00016: val_acc did not improve from 0.82812
# Epoch 17/100
# 13/13 [==============================] - 6s 491ms/step - loss: 0.1327 - acc: 0.9663 - val_loss: 0.8341 - val_acc: 0.7344
#
# Epoch 00017: val_acc did not improve from 0.82812
# Epoch 18/100
# 13/13 [==============================] - 6s 465ms/step - loss: 0.1363 - acc: 0.9507 - val_loss: 0.5882 - val_acc: 0.7344
#
# Epoch 00018: val_acc did not improve from 0.82812
# Epoch 19/100
# 13/13 [==============================] - 6s 487ms/step - loss: 0.0907 - acc: 0.9724 - val_loss: 1.1026 - val_acc: 0.7344
#
# Epoch 00019: val_acc did not improve from 0.82812
# Epoch 20/100
# 13/13 [==============================] - 6s 463ms/step - loss: 0.0530 - acc: 0.9844 - val_loss: 0.6970 - val_acc: 0.7812
#
# Epoch 00020: val_acc did not improve from 0.82812
# Epoch 21/100
# 13/13 [==============================] - 6s 463ms/step - loss: 0.0428 - acc: 0.9820 - val_loss: 0.9627 - val_acc: 0.8125
#
# Epoch 00021: val_acc did not improve from 0.82812
# Epoch 22/100
# 13/13 [==============================] - 6s 456ms/step - loss: 0.0662 - acc: 0.9760 - val_loss: 2.0993 - val_acc: 0.6719
#
# Epoch 00022: val_acc did not improve from 0.82812
# Epoch 23/100
# 13/13 [==============================] - 6s 460ms/step - loss: 0.4175 - acc: 0.8834 - val_loss: 0.4311 - val_acc: 0.7969
#
# Epoch 00023: val_acc did not improve from 0.82812
# Epoch 24/100
# 13/13 [==============================] - 6s 470ms/step - loss: 0.1186 - acc: 0.9603 - val_loss: 1.3787 - val_acc: 0.6562
#
# Epoch 00024: val_acc did not improve from 0.82812
# Epoch 25/100
# 13/13 [==============================] - 6s 470ms/step - loss: 0.2810 - acc: 0.8990 - val_loss: 0.5327 - val_acc: 0.8438
#
# Epoch 00025: val_acc improved from 0.82812 to 0.84375, saving model to CV/node_go_seq2-1.hdf5
# Epoch 26/100
# 13/13 [==============================] - 7s 521ms/step - loss: 0.1075 - acc: 0.9663 - val_loss: 0.6764 - val_acc: 0.7969
#
# Epoch 00026: val_acc did not improve from 0.84375
# Epoch 27/100
# 13/13 [==============================] - 7s 534ms/step - loss: 0.0822 - acc: 0.9760 - val_loss: 0.6599 - val_acc: 0.8281
#
# Epoch 00027: val_acc did not improve from 0.84375
# Epoch 28/100
# 13/13 [==============================] - 6s 469ms/step - loss: 0.0616 - acc: 0.9820 - val_loss: 0.8852 - val_acc: 0.8125
#
# Epoch 00028: val_acc did not improve from 0.84375
# Epoch 29/100
# 13/13 [==============================] - 6s 476ms/step - loss: 0.0996 - acc: 0.9736 - val_loss: 0.5728 - val_acc: 0.7188
#
# Epoch 00029: val_acc did not improve from 0.84375
# Epoch 30/100
# 13/13 [==============================] - 8s 597ms/step - loss: 0.0725 - acc: 0.9784 - val_loss: 0.8130 - val_acc: 0.7812
#
# Epoch 00030: val_acc did not improve from 0.84375
# Epoch 31/100
# 13/13 [==============================] - 8s 593ms/step - loss: 0.0712 - acc: 0.9724 - val_loss: 0.9605 - val_acc: 0.7812
#
# Epoch 00031: val_acc did not improve from 0.84375
# Epoch 32/100
# 13/13 [==============================] - 7s 575ms/step - loss: 0.0395 - acc: 0.9904 - val_loss: 0.7845 - val_acc: 0.8281
#
# Epoch 00032: val_acc did not improve from 0.84375
# Epoch 33/100
# 13/13 [==============================] - 8s 584ms/step - loss: 0.0230 - acc: 0.9904 - val_loss: 1.1413 - val_acc: 0.7969
#
# Epoch 00033: val_acc did not improve from 0.84375
# Epoch 34/100
# 13/13 [==============================] - 7s 571ms/step - loss: 0.0676 - acc: 0.9700 - val_loss: 1.0366 - val_acc: 0.7812
#
# Epoch 00034: val_acc did not improve from 0.84375
# Epoch 35/100
# 13/13 [==============================] - 8s 591ms/step - loss: 0.0547 - acc: 0.9844 - val_loss: 0.7897 - val_acc: 0.8281
#
# Epoch 00035: val_acc did not improve from 0.84375
# Epoch 36/100
# 13/13 [==============================] - 8s 594ms/step - loss: 0.0644 - acc: 0.9796 - val_loss: 0.5641 - val_acc: 0.8281
#
# Epoch 00036: val_acc did not improve from 0.84375
# Epoch 37/100
# 13/13 [==============================] - 8s 608ms/step - loss: 0.0377 - acc: 0.9868 - val_loss: 0.9986 - val_acc: 0.8125
#
# Epoch 00037: val_acc did not improve from 0.84375
# Epoch 38/100
# 13/13 [==============================] - 7s 577ms/step - loss: 0.0373 - acc: 0.9904 - val_loss: 0.8637 - val_acc: 0.8125
#
# Epoch 00038: val_acc did not improve from 0.84375
# Epoch 39/100
# 13/13 [==============================] - 7s 562ms/step - loss: 0.0396 - acc: 0.9880 - val_loss: 0.9784 - val_acc: 0.8125
#
# Epoch 00039: val_acc did not improve from 0.84375
# Epoch 40/100
# 13/13 [==============================] - 8s 579ms/step - loss: 0.0122 - acc: 0.9964 - val_loss: 1.1797 - val_acc: 0.7812
#
# Epoch 00040: val_acc did not improve from 0.84375
# Epoch 41/100
# 13/13 [==============================] - 8s 599ms/step - loss: 0.1259 - acc: 0.9531 - val_loss: 0.6774 - val_acc: 0.7969
#
# Epoch 00041: val_acc did not improve from 0.84375
# Epoch 42/100
# 13/13 [==============================] - 8s 612ms/step - loss: 0.0989 - acc: 0.9688 - val_loss: 0.9803 - val_acc: 0.7500
#
# Epoch 00042: val_acc did not improve from 0.84375
# Epoch 43/100
# 13/13 [==============================] - 8s 588ms/step - loss: 0.0684 - acc: 0.9820 - val_loss: 0.8515 - val_acc: 0.7812
#
# Epoch 00043: val_acc did not improve from 0.84375
# Epoch 44/100
# 13/13 [==============================] - 8s 600ms/step - loss: 0.0112 - acc: 0.9964 - val_loss: 1.6912 - val_acc: 0.7344
#
# Epoch 00044: val_acc did not improve from 0.84375
# Epoch 45/100
# 13/13 [==============================] - 8s 595ms/step - loss: 0.0448 - acc: 0.9928 - val_loss: 1.4840 - val_acc: 0.8125
#
# Epoch 00045: val_acc did not improve from 0.84375
# --------------------------
#
# AUC: 0.986895
# ACC: 0.944444
# MCC : 0.886889
# TPR:0.925373
# FPR:0.024390
# Pre:0.984127
# F1:0.953846
# --------------------------
#
# Epoch 1/100
# 13/13 [==============================] - 24s 2s/step - loss: 1.1425 - acc: 0.4796 - val_loss: 0.6886 - val_acc: 0.5000
# Epoch 00001: val_acc improved from -inf to 0.50000, saving model to CV/node_go_seq2-2.hdf5
# Epoch 2/100
# 13/13 [==============================] - 7s 531ms/step - loss: 0.7022 - acc: 0.5300 - val_loss: 0.7221 - val_acc: 0.5000
#
# Epoch 00002: val_acc did not improve from 0.50000
# Epoch 3/100
# 13/13 [==============================] - 7s 545ms/step - loss: 0.6178 - acc: 0.6575 - val_loss: 0.6383 - val_acc: 0.6562
#
# Epoch 00003: val_acc improved from 0.50000 to 0.65625, saving model to CV/node_go_seq2-2.hdf5
# Epoch 4/100
# 13/13 [==============================] - 6s 497ms/step - loss: 0.5422 - acc: 0.7260 - val_loss: 0.6419 - val_acc: 0.6250
#
# Epoch 00004: val_acc did not improve from 0.65625
# Epoch 5/100
# 13/13 [==============================] - 6s 429ms/step - loss: 0.6003 - acc: 0.7332 - val_loss: 0.6737 - val_acc: 0.6250
#
# Epoch 00005: val_acc did not improve from 0.65625
# Epoch 6/100
# 13/13 [==============================] - 5s 394ms/step - loss: 0.5458 - acc: 0.7200 - val_loss: 0.6147 - val_acc: 0.6250
#
# Epoch 00006: val_acc did not improve from 0.65625
# Epoch 7/100
# 13/13 [==============================] - 5s 416ms/step - loss: 0.4235 - acc: 0.8197 - val_loss: 0.5368 - val_acc: 0.7344
#
# Epoch 00007: val_acc improved from 0.65625 to 0.73438, saving model to CV/node_go_seq2-2.hdf5
# Epoch 8/100
# 13/13 [==============================] - 5s 413ms/step - loss: 0.3735 - acc: 0.8462 - val_loss: 0.6883 - val_acc: 0.6719
#
# Epoch 00008: val_acc did not improve from 0.73438
# Epoch 9/100
# 13/13 [==============================] - 6s 437ms/step - loss: 0.3579 - acc: 0.8510 - val_loss: 0.6286 - val_acc: 0.7188
#
# Epoch 00009: val_acc did not improve from 0.73438
# Epoch 10/100
# 13/13 [==============================] - 7s 504ms/step - loss: 0.2899 - acc: 0.8906 - val_loss: 0.5978 - val_acc: 0.7500
#
# Epoch 00010: val_acc improved from 0.73438 to 0.75000, saving model to CV/node_go_seq2-2.hdf5
# Epoch 11/100
# 13/13 [==============================] - 5s 418ms/step - loss: 0.2202 - acc: 0.9135 - val_loss: 0.6418 - val_acc: 0.7344
#
# Epoch 00011: val_acc did not improve from 0.75000
# Epoch 12/100
# 13/13 [==============================] - 5s 420ms/step - loss: 0.2105 - acc: 0.9195 - val_loss: 0.7267 - val_acc: 0.6719
#
# Epoch 00012: val_acc did not improve from 0.75000
# Epoch 13/100
# 13/13 [==============================] - 5s 398ms/step - loss: 0.1701 - acc: 0.9279 - val_loss: 0.6367 - val_acc: 0.7500
#
# Epoch 00013: val_acc did not improve from 0.75000
# Epoch 14/100
# 13/13 [==============================] - 5s 407ms/step - loss: 0.3242 - acc: 0.8762 - val_loss: 0.6293 - val_acc: 0.7344
#
# Epoch 00014: val_acc did not improve from 0.75000
# Epoch 15/100
# 13/13 [==============================] - 6s 458ms/step - loss: 0.2498 - acc: 0.8954 - val_loss: 0.6161 - val_acc: 0.6875
#
# Epoch 00015: val_acc did not improve from 0.75000
# Epoch 16/100
# 13/13 [==============================] - 7s 548ms/step - loss: 0.1200 - acc: 0.9579 - val_loss: 0.6556 - val_acc: 0.7812
#
# Epoch 00016: val_acc improved from 0.75000 to 0.78125, saving model to CV/node_go_seq2-2.hdf5
# Epoch 17/100
# 13/13 [==============================] - 7s 535ms/step - loss: 0.1392 - acc: 0.9387 - val_loss: 0.6297 - val_acc: 0.7656
#
# Epoch 00017: val_acc did not improve from 0.78125
# Epoch 18/100
# 13/13 [==============================] - 7s 511ms/step - loss: 0.1018 - acc: 0.9639 - val_loss: 0.7030 - val_acc: 0.8125
#
# Epoch 00018: val_acc improved from 0.78125 to 0.81250, saving model to CV/node_go_seq2-2.hdf5
# Epoch 19/100
# 13/13 [==============================] - 7s 546ms/step - loss: 0.1003 - acc: 0.9663 - val_loss: 1.0394 - val_acc: 0.7656
#
# Epoch 00019: val_acc did not improve from 0.81250
# Epoch 20/100
# 13/13 [==============================] - 7s 535ms/step - loss: 0.1884 - acc: 0.9243 - val_loss: 0.5460 - val_acc: 0.7656
#
# Epoch 00020: val_acc did not improve from 0.81250
# Epoch 21/100
# 13/13 [==============================] - 7s 546ms/step - loss: 0.1292 - acc: 0.9471 - val_loss: 0.7667 - val_acc: 0.7656
#
# Epoch 00021: val_acc did not improve from 0.81250
# Epoch 22/100
# 13/13 [==============================] - 7s 517ms/step - loss: 0.1307 - acc: 0.9555 - val_loss: 1.1174 - val_acc: 0.7188
#
# Epoch 00022: val_acc did not improve from 0.81250
# Epoch 23/100
# 13/13 [==============================] - 8s 590ms/step - loss: 0.1301 - acc: 0.9483 - val_loss: 0.9617 - val_acc: 0.7812
#
# Epoch 00023: val_acc did not improve from 0.81250
# Epoch 24/100
# 13/13 [==============================] - 7s 576ms/step - loss: 0.1353 - acc: 0.9519 - val_loss: 0.8995 - val_acc: 0.7656
#
# Epoch 00024: val_acc did not improve from 0.81250
# Epoch 25/100
# 13/13 [==============================] - 7s 547ms/step - loss: 0.2359 - acc: 0.9207 - val_loss: 0.6394 - val_acc: 0.7344
#
# Epoch 00025: val_acc did not improve from 0.81250
# Epoch 26/100
# 13/13 [==============================] - 7s 515ms/step - loss: 0.1072 - acc: 0.9627 - val_loss: 0.7857 - val_acc: 0.7656
#
# Epoch 00026: val_acc did not improve from 0.81250
# Epoch 27/100
# 13/13 [==============================] - 7s 537ms/step - loss: 0.0658 - acc: 0.9748 - val_loss: 1.0592 - val_acc: 0.7812
#
# Epoch 00027: val_acc did not improve from 0.81250
# Epoch 28/100
# 13/13 [==============================] - 7s 523ms/step - loss: 0.0646 - acc: 0.9796 - val_loss: 1.0357 - val_acc: 0.7656
#
# Epoch 00028: val_acc did not improve from 0.81250
# Epoch 29/100
# 13/13 [==============================] - 7s 511ms/step - loss: 0.1518 - acc: 0.9399 - val_loss: 0.5309 - val_acc: 0.7812
#
# Epoch 00029: val_acc did not improve from 0.81250
# Epoch 30/100
# 13/13 [==============================] - 6s 499ms/step - loss: 0.0759 - acc: 0.9724 - val_loss: 0.9466 - val_acc: 0.8125
#
# Epoch 00030: val_acc did not improve from 0.81250
# Epoch 31/100
# 13/13 [==============================] - 6s 500ms/step - loss: 0.0376 - acc: 0.9844 - val_loss: 1.1974 - val_acc: 0.7188
#
# Epoch 00031: val_acc did not improve from 0.81250
# Epoch 32/100
# 13/13 [==============================] - 7s 500ms/step - loss: 0.0642 - acc: 0.9748 - val_loss: 1.0233 - val_acc: 0.7031
#
# Epoch 00032: val_acc did not improve from 0.81250
# Epoch 33/100
# 13/13 [==============================] - 7s 513ms/step - loss: 0.0738 - acc: 0.9772 - val_loss: 0.9376 - val_acc: 0.7812
#
# Epoch 00033: val_acc did not improve from 0.81250
# Epoch 34/100
# 13/13 [==============================] - 7s 543ms/step - loss: 0.0413 - acc: 0.9820 - val_loss: 1.1681 - val_acc: 0.7500
#
# Epoch 00034: val_acc did not improve from 0.81250
# Epoch 35/100
# 13/13 [==============================] - 7s 512ms/step - loss: 0.0877 - acc: 0.9724 - val_loss: 0.7755 - val_acc: 0.7812
#
# Epoch 00035: val_acc did not improve from 0.81250
# Epoch 36/100
# 13/13 [==============================] - 7s 527ms/step - loss: 0.0561 - acc: 0.9784 - val_loss: 0.8512 - val_acc: 0.7500
#
# Epoch 00036: val_acc did not improve from 0.81250
# Epoch 37/100
# 13/13 [==============================] - 7s 523ms/step - loss: 0.0332 - acc: 0.9916 - val_loss: 1.2826 - val_acc: 0.7344
#
# Epoch 00037: val_acc did not improve from 0.81250
# Epoch 38/100
# 13/13 [==============================] - 7s 518ms/step - loss: 0.2348 - acc: 0.9123 - val_loss: 0.5467 - val_acc: 0.7812
#
# Epoch 00038: val_acc did not improve from 0.81250
# --------------------------
#
# AUC: 0.982363
# ACC: 0.935185
# MCC : 0.867245
# TPR:0.933333
# FPR:0.063492
# Pre:0.913043
# F1:0.923077
# --------------------------
#
# Epoch 1/100
# 13/13 [==============================] - 25s 2s/step - loss: 1.0206 - acc: 0.5024 - val_loss: 0.6863 - val_acc: 0.5000
#
# Epoch 00001: val_acc improved from -inf to 0.50000, saving model to CV/node_go_seq2-3.hdf5
# Epoch 2/100
# 13/13 [==============================] - 5s 406ms/step - loss: 0.6585 - acc: 0.6310 - val_loss: 0.8739 - val_acc: 0.6094
#
# Epoch 00002: val_acc improved from 0.50000 to 0.60938, saving model to CV/node_go_seq2-3.hdf5
# Epoch 3/100
# 13/13 [==============================] - 6s 435ms/step - loss: 0.6430 - acc: 0.6418 - val_loss: 0.7709 - val_acc: 0.5156
#
# Epoch 00003: val_acc did not improve from 0.60938
# Epoch 4/100
# 13/13 [==============================] - 5s 393ms/step - loss: 0.5666 - acc: 0.7151 - val_loss: 0.7010 - val_acc: 0.5938
#
# Epoch 00004: val_acc did not improve from 0.60938
# Epoch 5/100
# 13/13 [==============================] - 5s 417ms/step - loss: 0.4887 - acc: 0.7656 - val_loss: 0.7213 - val_acc: 0.5312
#
# Epoch 00005: val_acc did not improve from 0.60938
# Epoch 6/100
# 13/13 [==============================] - 5s 417ms/step - loss: 0.4772 - acc: 0.7825 - val_loss: 0.7326 - val_acc: 0.6719
#
# Epoch 00006: val_acc improved from 0.60938 to 0.67188, saving model to CV/node_go_seq2-3.hdf5
# Epoch 7/100
# 13/13 [==============================] - 6s 430ms/step - loss: 0.3991 - acc: 0.8293 - val_loss: 0.6422 - val_acc: 0.6719
#
# Epoch 00007: val_acc did not improve from 0.67188
# Epoch 8/100
# 13/13 [==============================] - 7s 513ms/step - loss: 0.3407 - acc: 0.8582 - val_loss: 0.6594 - val_acc: 0.6562
#
# Epoch 00008: val_acc did not improve from 0.67188
# Epoch 9/100
# 13/13 [==============================] - 6s 435ms/step - loss: 0.2536 - acc: 0.8870 - val_loss: 0.7613 - val_acc: 0.7188
#
# Epoch 00009: val_acc improved from 0.67188 to 0.71875, saving model to CV/node_go_seq2-3.hdf5
# Epoch 10/100
# 13/13 [==============================] - 5s 406ms/step - loss: 0.2523 - acc: 0.9014 - val_loss: 0.9575 - val_acc: 0.5938
#
# Epoch 00010: val_acc did not improve from 0.71875
# Epoch 11/100
# 13/13 [==============================] - 5s 417ms/step - loss: 0.3329 - acc: 0.8630 - val_loss: 0.7517 - val_acc: 0.7031
#
# Epoch 00011: val_acc did not improve from 0.71875
# Epoch 12/100
# 13/13 [==============================] - 5s 419ms/step - loss: 0.3758 - acc: 0.8413 - val_loss: 0.6356 - val_acc: 0.6562
#
# Epoch 00012: val_acc did not improve from 0.71875
# Epoch 13/100
# 13/13 [==============================] - 5s 408ms/step - loss: 0.2583 - acc: 0.8930 - val_loss: 0.8956 - val_acc: 0.6875
#
# Epoch 00013: val_acc did not improve from 0.71875
# Epoch 14/100
# 13/13 [==============================] - 6s 443ms/step - loss: 0.2177 - acc: 0.9075 - val_loss: 0.6646 - val_acc: 0.7344
#
# Epoch 00014: val_acc improved from 0.71875 to 0.73438, saving model to CV/node_go_seq2-3.hdf5
# Epoch 15/100
# 13/13 [==============================] - 5s 415ms/step - loss: 0.1480 - acc: 0.9363 - val_loss: 0.9535 - val_acc: 0.7188
#
# Epoch 00015: val_acc did not improve from 0.73438
# Epoch 16/100
# 13/13 [==============================] - 7s 502ms/step - loss: 0.1315 - acc: 0.9483 - val_loss: 0.7544 - val_acc: 0.7500
#
# Epoch 00016: val_acc improved from 0.73438 to 0.75000, saving model to CV/node_go_seq2-3.hdf5
# Epoch 17/100
# 13/13 [==============================] - 7s 534ms/step - loss: 0.1050 - acc: 0.9567 - val_loss: 0.7583 - val_acc: 0.7500
#
# Epoch 00017: val_acc did not improve from 0.75000
# Epoch 18/100
# 13/13 [==============================] - 7s 513ms/step - loss: 0.0909 - acc: 0.9639 - val_loss: 1.0095 - val_acc: 0.7031
#
# Epoch 00018: val_acc did not improve from 0.75000
# Epoch 19/100
# 13/13 [==============================] - 7s 517ms/step - loss: 0.1247 - acc: 0.9579 - val_loss: 0.9035 - val_acc: 0.7656
#
# Epoch 00019: val_acc improved from 0.75000 to 0.76562, saving model to CV/node_go_seq2-3.hdf5
# Epoch 20/100
# 13/13 [==============================] - 7s 518ms/step - loss: 0.0969 - acc: 0.9760 - val_loss: 1.0910 - val_acc: 0.7656
#
# Epoch 00020: val_acc did not improve from 0.76562
# Epoch 21/100
# 13/13 [==============================] - 7s 513ms/step - loss: 0.0973 - acc: 0.9688 - val_loss: 0.9748 - val_acc: 0.7656
#
# Epoch 00021: val_acc did not improve from 0.76562
# Epoch 22/100
# 13/13 [==============================] - 7s 519ms/step - loss: 0.0649 - acc: 0.9760 - val_loss: 0.8812 - val_acc: 0.7188
#
# Epoch 00022: val_acc did not improve from 0.76562
# Epoch 23/100
# 13/13 [==============================] - 7s 519ms/step - loss: 0.0290 - acc: 0.9892 - val_loss: 1.0819 - val_acc: 0.7188
#
# Epoch 00023: val_acc did not improve from 0.76562
# Epoch 24/100
# 13/13 [==============================] - 7s 509ms/step - loss: 0.0329 - acc: 0.9880 - val_loss: 1.2019 - val_acc: 0.7344
#
# Epoch 00024: val_acc did not improve from 0.76562
# Epoch 25/100
# 13/13 [==============================] - 7s 547ms/step - loss: 0.0941 - acc: 0.9688 - val_loss: 1.1472 - val_acc: 0.6875
#
# Epoch 00025: val_acc did not improve from 0.76562
# Epoch 26/100
# 13/13 [==============================] - 7s 533ms/step - loss: 0.1124 - acc: 0.9651 - val_loss: 0.8544 - val_acc: 0.6875
#
# Epoch 00026: val_acc did not improve from 0.76562
# Epoch 27/100
# 13/13 [==============================] - 7s 546ms/step - loss: 0.0722 - acc: 0.9712 - val_loss: 0.9664 - val_acc: 0.7188
#
# Epoch 00027: val_acc did not improve from 0.76562
# Epoch 28/100
# 13/13 [==============================] - 7s 553ms/step - loss: 0.0696 - acc: 0.9772 - val_loss: 0.9573 - val_acc: 0.7500
#
# Epoch 00028: val_acc did not improve from 0.76562
# Epoch 29/100
# 13/13 [==============================] - 7s 534ms/step - loss: 0.0455 - acc: 0.9892 - val_loss: 0.9247 - val_acc: 0.7500
#
# Epoch 00029: val_acc did not improve from 0.76562
# Epoch 30/100
# 13/13 [==============================] - 7s 532ms/step - loss: 0.0357 - acc: 0.9856 - val_loss: 1.2017 - val_acc: 0.7031
#
# Epoch 00030: val_acc did not improve from 0.76562
# Epoch 31/100
# 13/13 [==============================] - 7s 529ms/step - loss: 0.0642 - acc: 0.9760 - val_loss: 1.1045 - val_acc: 0.6719
#
# Epoch 00031: val_acc did not improve from 0.76562
# Epoch 32/100
# 13/13 [==============================] - 7s 528ms/step - loss: 0.0440 - acc: 0.9820 - val_loss: 1.0829 - val_acc: 0.7344
#
# Epoch 00032: val_acc did not improve from 0.76562
# Epoch 33/100
# 13/13 [==============================] - 7s 544ms/step - loss: 0.0361 - acc: 0.9880 - val_loss: 1.3098 - val_acc: 0.6719
#
# Epoch 00033: val_acc did not improve from 0.76562
# Epoch 34/100
# 13/13 [==============================] - 7s 537ms/step - loss: 0.0149 - acc: 0.9928 - val_loss: 1.6334 - val_acc: 0.7344
#
# Epoch 00034: val_acc did not improve from 0.76562
# Epoch 35/100
# 13/13 [==============================] - 7s 521ms/step - loss: 0.1022 - acc: 0.9663 - val_loss: 1.0179 - val_acc: 0.7031
#
# Epoch 00035: val_acc did not improve from 0.76562
# Epoch 36/100
# 13/13 [==============================] - 7s 537ms/step - loss: 0.0978 - acc: 0.9603 - val_loss: 0.8103 - val_acc: 0.7344
#
# Epoch 00036: val_acc did not improve from 0.76562
# Epoch 37/100
# 13/13 [==============================] - 7s 521ms/step - loss: 0.0641 - acc: 0.9772 - val_loss: 1.1652 - val_acc: 0.6562
#
# Epoch 00037: val_acc did not improve from 0.76562
# Epoch 38/100
# 13/13 [==============================] - 7s 553ms/step - loss: 0.0265 - acc: 0.9880 - val_loss: 1.2683 - val_acc: 0.7031
#
# Epoch 00038: val_acc did not improve from 0.76562
# Epoch 39/100
# 13/13 [==============================] - 7s 541ms/step - loss: 0.0147 - acc: 0.9916 - val_loss: 1.4441 - val_acc: 0.6875
#
# Epoch 00039: val_acc did not improve from 0.76562
# --------------------------
#
# AUC: 0.970370
# ACC: 0.925926
# MCC : 0.849189
# TPR:0.933333
# FPR:0.079365
# Pre:0.893617
# F1:0.913043
# --------------------------
#
# Epoch 1/100
# 13/13 [==============================] - 29s 2s/step - loss: 0.8933 - acc: 0.5300 - val_loss: 0.6773 - val_acc: 0.5156
#
# Epoch 00001: val_acc improved from -inf to 0.51562, saving model to CV/node_go_seq2-4.hdf5
# Epoch 2/100
# 13/13 [==============================] - 7s 573ms/step - loss: 0.6748 - acc: 0.5829 - val_loss: 0.6471 - val_acc: 0.6094
#
# Epoch 00002: val_acc improved from 0.51562 to 0.60938, saving model to CV/node_go_seq2-4.hdf5
# Epoch 3/100
# 13/13 [==============================] - 8s 631ms/step - loss: 0.5742 - acc: 0.7308 - val_loss: 0.8046 - val_acc: 0.5469
#
# Epoch 00003: val_acc did not improve from 0.60938
# Epoch 4/100
# 13/13 [==============================] - 7s 528ms/step - loss: 0.6056 - acc: 0.6923 - val_loss: 0.6905 - val_acc: 0.5938
#
# Epoch 00004: val_acc did not improve from 0.60938
# Epoch 5/100
# 13/13 [==============================] - 8s 585ms/step - loss: 0.4712 - acc: 0.7740 - val_loss: 1.0690 - val_acc: 0.5156
#
# Epoch 00005: val_acc did not improve from 0.60938
# Epoch 6/100
# 13/13 [==============================] - 8s 585ms/step - loss: 0.4886 - acc: 0.7716 - val_loss: 0.6259 - val_acc: 0.6875
#
# Epoch 00006: val_acc improved from 0.60938 to 0.68750, saving model to CV/node_go_seq2-4.hdf5
# Epoch 7/100
# 13/13 [==============================] - 7s 555ms/step - loss: 0.3626 - acc: 0.8522 - val_loss: 0.6248 - val_acc: 0.6562
#
# Epoch 00007: val_acc did not improve from 0.68750
# Epoch 8/100
# 13/13 [==============================] - 7s 538ms/step - loss: 0.3023 - acc: 0.8870 - val_loss: 0.6483 - val_acc: 0.7188
#
# Epoch 00008: val_acc improved from 0.68750 to 0.71875, saving model to CV/node_go_seq2-4.hdf5
# Epoch 9/100
# 13/13 [==============================] - 7s 566ms/step - loss: 0.4415 - acc: 0.7945 - val_loss: 0.5831 - val_acc: 0.7188
#
# Epoch 00009: val_acc did not improve from 0.71875
# Epoch 10/100
# 13/13 [==============================] - 7s 570ms/step - loss: 0.2817 - acc: 0.8858 - val_loss: 0.6649 - val_acc: 0.7031
#
# Epoch 00010: val_acc did not improve from 0.71875
# Epoch 11/100
# 13/13 [==============================] - 7s 500ms/step - loss: 0.2905 - acc: 0.8774 - val_loss: 0.9448 - val_acc: 0.6406
#
# Epoch 00011: val_acc did not improve from 0.71875
# Epoch 12/100
# 13/13 [==============================] - 6s 461ms/step - loss: 0.4168 - acc: 0.8365 - val_loss: 0.7290 - val_acc: 0.6094
#
# Epoch 00012: val_acc did not improve from 0.71875
# Epoch 13/100
# 13/13 [==============================] - 6s 491ms/step - loss: 0.2747 - acc: 0.8906 - val_loss: 0.8531 - val_acc: 0.6562
#
# Epoch 00013: val_acc did not improve from 0.71875
# Epoch 14/100
# 13/13 [==============================] - 6s 466ms/step - loss: 0.1824 - acc: 0.9327 - val_loss: 0.8480 - val_acc: 0.5938
#
# Epoch 00014: val_acc did not improve from 0.71875
# Epoch 15/100
# 13/13 [==============================] - 6s 473ms/step - loss: 0.2344 - acc: 0.8918 - val_loss: 0.8321 - val_acc: 0.5938
#
# Epoch 00015: val_acc did not improve from 0.71875
# Epoch 16/100
# 13/13 [==============================] - 6s 464ms/step - loss: 0.1343 - acc: 0.9459 - val_loss: 1.0542 - val_acc: 0.6562
#
# Epoch 00016: val_acc did not improve from 0.71875
# Epoch 17/100
# 13/13 [==============================] - 7s 520ms/step - loss: 0.1014 - acc: 0.9555 - val_loss: 1.7364 - val_acc: 0.6406
#
# Epoch 00017: val_acc did not improve from 0.71875
# Epoch 18/100
# 13/13 [==============================] - 7s 549ms/step - loss: 0.1167 - acc: 0.9507 - val_loss: 1.0428 - val_acc: 0.6875
#
# Epoch 00018: val_acc did not improve from 0.71875
# Epoch 19/100
# 13/13 [==============================] - 6s 471ms/step - loss: 0.1505 - acc: 0.9339 - val_loss: 1.1822 - val_acc: 0.6406
#
# Epoch 00019: val_acc did not improve from 0.71875
# Epoch 20/100
# 13/13 [==============================] - 6s 461ms/step - loss: 0.1582 - acc: 0.9351 - val_loss: 1.1774 - val_acc: 0.6406
#
# Epoch 00020: val_acc did not improve from 0.71875
# Epoch 21/100
# 13/13 [==============================] - 6s 448ms/step - loss: 0.1124 - acc: 0.9663 - val_loss: 1.6779 - val_acc: 0.6719
#
# Epoch 00021: val_acc did not improve from 0.71875
# Epoch 22/100
# 13/13 [==============================] - 6s 458ms/step - loss: 0.0823 - acc: 0.9712 - val_loss: 1.1227 - val_acc: 0.7656
#
# Epoch 00022: val_acc improved from 0.71875 to 0.76562, saving model to CV/node_go_seq2-4.hdf5
# Epoch 23/100
# 13/13 [==============================] - 6s 477ms/step - loss: 0.0789 - acc: 0.9675 - val_loss: 1.5893 - val_acc: 0.6875
#
# Epoch 00023: val_acc did not improve from 0.76562
# Epoch 24/100
# 13/13 [==============================] - 6s 463ms/step - loss: 0.0725 - acc: 0.9760 - val_loss: 1.3604 - val_acc: 0.6875
#
# Epoch 00024: val_acc did not improve from 0.76562
# Epoch 25/100
# 13/13 [==============================] - 6s 484ms/step - loss: 0.1038 - acc: 0.9651 - val_loss: 1.5871 - val_acc: 0.6562
#
# Epoch 00025: val_acc did not improve from 0.76562
# Epoch 26/100
# 13/13 [==============================] - 6s 473ms/step - loss: 0.0769 - acc: 0.9712 - val_loss: 1.9131 - val_acc: 0.6094
#
# Epoch 00026: val_acc did not improve from 0.76562
# Epoch 27/100
# 13/13 [==============================] - 5s 403ms/step - loss: 0.0712 - acc: 0.9724 - val_loss: 1.7868 - val_acc: 0.6250
#
# Epoch 00027: val_acc did not improve from 0.76562
# Epoch 28/100
# 13/13 [==============================] - 7s 514ms/step - loss: 0.0586 - acc: 0.9748 - val_loss: 1.9952 - val_acc: 0.5938
#
# Epoch 00028: val_acc did not improve from 0.76562
# Epoch 29/100
# 13/13 [==============================] - 7s 504ms/step - loss: 0.0364 - acc: 0.9832 - val_loss: 1.8242 - val_acc: 0.7188
#
# Epoch 00029: val_acc did not improve from 0.76562
# Epoch 30/100
# 13/13 [==============================] - 7s 573ms/step - loss: 0.0495 - acc: 0.9868 - val_loss: 1.7138 - val_acc: 0.6875
#
# Epoch 00030: val_acc did not improve from 0.76562
# Epoch 31/100
# 13/13 [==============================] - 7s 573ms/step - loss: 0.0982 - acc: 0.9651 - val_loss: 1.3126 - val_acc: 0.7344
#
# Epoch 00031: val_acc did not improve from 0.76562
# Epoch 32/100
# 13/13 [==============================] - 7s 554ms/step - loss: 0.0812 - acc: 0.9663 - val_loss: 1.1353 - val_acc: 0.6875
#
# Epoch 00032: val_acc did not improve from 0.76562
# Epoch 33/100
# 13/13 [==============================] - 7s 528ms/step - loss: 0.0730 - acc: 0.9748 - val_loss: 1.6972 - val_acc: 0.6562
#
# Epoch 00033: val_acc did not improve from 0.76562
# Epoch 34/100
# 13/13 [==============================] - 7s 574ms/step - loss: 0.0389 - acc: 0.9868 - val_loss: 1.7144 - val_acc: 0.6562
#
# Epoch 00034: val_acc did not improve from 0.76562
# Epoch 35/100
# 13/13 [==============================] - 7s 548ms/step - loss: 0.0356 - acc: 0.9856 - val_loss: 1.6886 - val_acc: 0.6562
#
# Epoch 00035: val_acc did not improve from 0.76562
# Epoch 36/100
# 13/13 [==============================] - 8s 602ms/step - loss: 0.0319 - acc: 0.9880 - val_loss: 2.1065 - val_acc: 0.6719
#
# Epoch 00036: val_acc did not improve from 0.76562
# Epoch 37/100
# 13/13 [==============================] - 8s 577ms/step - loss: 0.0230 - acc: 0.9904 - val_loss: 1.9615 - val_acc: 0.6875
#
# Epoch 00037: val_acc did not improve from 0.76562
# Epoch 38/100
# 13/13 [==============================] - 7s 572ms/step - loss: 0.0553 - acc: 0.9880 - val_loss: 2.1443 - val_acc: 0.6562
#
# Epoch 00038: val_acc did not improve from 0.76562
# Epoch 39/100
# 13/13 [==============================] - 7s 571ms/step - loss: 0.0507 - acc: 0.9808 - val_loss: 1.9762 - val_acc: 0.6562
#
# Epoch 00039: val_acc did not improve from 0.76562
# Epoch 40/100
# 13/13 [==============================] - 8s 588ms/step - loss: 0.0545 - acc: 0.9856 - val_loss: 1.6391 - val_acc: 0.6406
#
# Epoch 00040: val_acc did not improve from 0.76562
# Epoch 41/100
# 13/13 [==============================] - 7s 573ms/step - loss: 0.0321 - acc: 0.9904 - val_loss: 1.9380 - val_acc: 0.7031
#
# Epoch 00041: val_acc did not improve from 0.76562
# Epoch 42/100
# 13/13 [==============================] - 8s 627ms/step - loss: 0.0200 - acc: 0.9904 - val_loss: 2.6627 - val_acc: 0.6250
#
# Epoch 00042: val_acc did not improve from 0.76562
# --------------------------
#
# AUC: 0.964912
# ACC: 0.944444
# MCC : 0.889386
# TPR:0.960784
# FPR:0.070175
# Pre:0.924528
# F1:0.942308
# --------------------------
#
# Epoch 1/100
# 13/13 [==============================] - 30s 2s/step - loss: 1.1435 - acc: 0.4928 - val_loss: 0.6657 - val_acc: 0.6562
#
# Epoch 00001: val_acc improved from -inf to 0.65625, saving model to CV/node_go_seq2-5.hdf5
# Epoch 2/100
# 13/13 [==============================] - 5s 401ms/step - loss: 0.6468 - acc: 0.6130 - val_loss: 0.5743 - val_acc: 0.6562
#
# Epoch 00002: val_acc did not improve from 0.65625
# Epoch 3/100
# 13/13 [==============================] - 5s 399ms/step - loss: 0.5766 - acc: 0.7019 - val_loss: 0.6029 - val_acc: 0.6719
#
# Epoch 00003: val_acc improved from 0.65625 to 0.67188, saving model to CV/node_go_seq2-5.hdf5
# Epoch 4/100
# 13/13 [==============================] - 5s 382ms/step - loss: 0.4914 - acc: 0.7764 - val_loss: 0.5433 - val_acc: 0.6406
#
# Epoch 00004: val_acc did not improve from 0.67188
# Epoch 5/100
# 13/13 [==============================] - 5s 400ms/step - loss: 0.4122 - acc: 0.8281 - val_loss: 0.5033 - val_acc: 0.7656
#
# Epoch 00005: val_acc improved from 0.67188 to 0.76562, saving model to CV/node_go_seq2-5.hdf5
# Epoch 6/100
# 13/13 [==============================] - 6s 430ms/step - loss: 0.4051 - acc: 0.8101 - val_loss: 0.5241 - val_acc: 0.7344
#
# Epoch 00006: val_acc did not improve from 0.76562
# Epoch 7/100
# 13/13 [==============================] - 5s 397ms/step - loss: 0.4707 - acc: 0.7668 - val_loss: 0.5633 - val_acc: 0.6875
#
# Epoch 00007: val_acc did not improve from 0.76562
# Epoch 8/100
# 13/13 [==============================] - 5s 406ms/step - loss: 0.3345 - acc: 0.8642 - val_loss: 0.7907 - val_acc: 0.6562
#
# Epoch 00008: val_acc did not improve from 0.76562
# Epoch 9/100
# 13/13 [==============================] - 6s 424ms/step - loss: 0.2544 - acc: 0.9026 - val_loss: 0.7825 - val_acc: 0.6719
#
# Epoch 00009: val_acc did not improve from 0.76562
# Epoch 10/100
# 13/13 [==============================] - 6s 446ms/step - loss: 0.2808 - acc: 0.8666 - val_loss: 0.5425 - val_acc: 0.6875
#
# Epoch 00010: val_acc did not improve from 0.76562
# Epoch 11/100
# 13/13 [==============================] - 6s 445ms/step - loss: 0.2637 - acc: 0.8978 - val_loss: 0.5950 - val_acc: 0.7500
#
# Epoch 00011: val_acc did not improve from 0.76562
# Epoch 12/100
# 13/13 [==============================] - 7s 522ms/step - loss: 0.2113 - acc: 0.9135 - val_loss: 0.5639 - val_acc: 0.7500
#
# Epoch 00012: val_acc did not improve from 0.76562
# Epoch 13/100
# 13/13 [==============================] - 7s 532ms/step - loss: 0.4560 - acc: 0.7933 - val_loss: 0.5399 - val_acc: 0.7031
#
# Epoch 00013: val_acc did not improve from 0.76562
# Epoch 14/100
# 13/13 [==============================] - 7s 525ms/step - loss: 0.3057 - acc: 0.8762 - val_loss: 0.5789 - val_acc: 0.7031
#
# Epoch 00014: val_acc did not improve from 0.76562
# Epoch 15/100
# 13/13 [==============================] - 7s 546ms/step - loss: 0.3472 - acc: 0.8450 - val_loss: 0.6555 - val_acc: 0.7500
#
# Epoch 00015: val_acc did not improve from 0.76562
# Epoch 16/100
# 13/13 [==============================] - 7s 542ms/step - loss: 0.2052 - acc: 0.9159 - val_loss: 0.7555 - val_acc: 0.6875
#
# Epoch 00016: val_acc did not improve from 0.76562
# Epoch 17/100
# 13/13 [==============================] - 7s 523ms/step - loss: 0.2250 - acc: 0.9219 - val_loss: 0.6399 - val_acc: 0.6719
#
# Epoch 00017: val_acc did not improve from 0.76562
# Epoch 18/100
# 13/13 [==============================] - 7s 502ms/step - loss: 0.1542 - acc: 0.9387 - val_loss: 0.9585 - val_acc: 0.6875
#
# Epoch 00018: val_acc did not improve from 0.76562
# Epoch 19/100
# 13/13 [==============================] - 7s 525ms/step - loss: 0.1722 - acc: 0.9387 - val_loss: 0.6831 - val_acc: 0.7031
#
# Epoch 00019: val_acc did not improve from 0.76562
# Epoch 20/100
# 13/13 [==============================] - 7s 527ms/step - loss: 0.1528 - acc: 0.9423 - val_loss: 0.9774 - val_acc: 0.6250
#
# Epoch 00020: val_acc did not improve from 0.76562
# Epoch 21/100
# 13/13 [==============================] - 7s 509ms/step - loss: 0.1073 - acc: 0.9531 - val_loss: 1.2428 - val_acc: 0.6562
#
# Epoch 00021: val_acc did not improve from 0.76562
# Epoch 22/100
# 13/13 [==============================] - 6s 496ms/step - loss: 0.1095 - acc: 0.9603 - val_loss: 0.8035 - val_acc: 0.7344
#
# Epoch 00022: val_acc did not improve from 0.76562
# Epoch 23/100
# 13/13 [==============================] - 7s 527ms/step - loss: 0.0875 - acc: 0.9627 - val_loss: 1.7948 - val_acc: 0.6094
#
# Epoch 00023: val_acc did not improve from 0.76562
# Epoch 24/100
# 13/13 [==============================] - 7s 560ms/step - loss: 0.1350 - acc: 0.9447 - val_loss: 0.9713 - val_acc: 0.6875
#
# Epoch 00024: val_acc did not improve from 0.76562
# Epoch 25/100
# 13/13 [==============================] - 7s 539ms/step - loss: 0.0594 - acc: 0.9784 - val_loss: 0.8621 - val_acc: 0.7500
#
# Epoch 00025: val_acc did not improve from 0.76562
# --------------------------
#
# AUC: 0.942414
# ACC: 0.824074
# MCC : 0.679308
# TPR:0.706897
# FPR:0.040000
# Pre:0.953488
# F1:0.811881
# --------------------------
#
# Epoch 1/100
# 13/13 [==============================] - 34s 3s/step - loss: 1.0003 - acc: 0.4820 - val_loss: 0.6844 - val_acc: 0.5469
#
# Epoch 00001: val_acc improved from -inf to 0.54688, saving model to CV/node_go_seq2-6.hdf5
# Epoch 2/100
# 13/13 [==============================] - 6s 498ms/step - loss: 0.7165 - acc: 0.5156 - val_loss: 0.6424 - val_acc: 0.6875
#
# Epoch 00002: val_acc improved from 0.54688 to 0.68750, saving model to CV/node_go_seq2-6.hdf5
# Epoch 3/100
# 13/13 [==============================] - 6s 482ms/step - loss: 0.6322 - acc: 0.6250 - val_loss: 0.5596 - val_acc: 0.7344
#
# Epoch 00003: val_acc improved from 0.68750 to 0.73438, saving model to CV/node_go_seq2-6.hdf5
# Epoch 4/100
# 13/13 [==============================] - 6s 493ms/step - loss: 0.6202 - acc: 0.6502 - val_loss: 0.6917 - val_acc: 0.4844
#
# Epoch 00004: val_acc did not improve from 0.73438
# Epoch 5/100
# 13/13 [==============================] - 6s 485ms/step - loss: 0.5706 - acc: 0.6971 - val_loss: 0.4906 - val_acc: 0.7812
#
# Epoch 00005: val_acc improved from 0.73438 to 0.78125, saving model to CV/node_go_seq2-6.hdf5
# Epoch 6/100
# 13/13 [==============================] - 6s 492ms/step - loss: 0.4682 - acc: 0.7764 - val_loss: 0.5468 - val_acc: 0.7188
#
# Epoch 00006: val_acc did not improve from 0.78125
# Epoch 7/100
# 13/13 [==============================] - 7s 503ms/step - loss: 0.4656 - acc: 0.7873 - val_loss: 0.5552 - val_acc: 0.7344
#
# Epoch 00007: val_acc did not improve from 0.78125
# Epoch 8/100
# 13/13 [==============================] - 7s 516ms/step - loss: 0.3526 - acc: 0.8474 - val_loss: 0.6146 - val_acc: 0.7188
#
# Epoch 00008: val_acc did not improve from 0.78125
# Epoch 9/100
# 13/13 [==============================] - 6s 495ms/step - loss: 0.2869 - acc: 0.8726 - val_loss: 0.4979 - val_acc: 0.8125
#
# Epoch 00009: val_acc improved from 0.78125 to 0.81250, saving model to CV/node_go_seq2-6.hdf5
# Epoch 10/100
# 13/13 [==============================] - 6s 497ms/step - loss: 0.3405 - acc: 0.8389 - val_loss: 0.4680 - val_acc: 0.8125
#
# Epoch 00010: val_acc did not improve from 0.81250
# Epoch 11/100
# 13/13 [==============================] - 7s 504ms/step - loss: 0.3311 - acc: 0.8726 - val_loss: 0.5995 - val_acc: 0.7344
#
# Epoch 00011: val_acc did not improve from 0.81250
# Epoch 12/100
# 13/13 [==============================] - 7s 512ms/step - loss: 0.3339 - acc: 0.8257 - val_loss: 0.4733 - val_acc: 0.8438
#
# Epoch 00012: val_acc improved from 0.81250 to 0.84375, saving model to CV/node_go_seq2-6.hdf5
# Epoch 13/100
# 13/13 [==============================] - 6s 482ms/step - loss: 0.1997 - acc: 0.9159 - val_loss: 0.5652 - val_acc: 0.7969
#
# Epoch 00013: val_acc did not improve from 0.84375
# Epoch 14/100
# 13/13 [==============================] - 6s 485ms/step - loss: 0.1720 - acc: 0.9267 - val_loss: 0.9023 - val_acc: 0.7188
#
# Epoch 00014: val_acc did not improve from 0.84375
# Epoch 15/100
# 13/13 [==============================] - 7s 549ms/step - loss: 0.2086 - acc: 0.9123 - val_loss: 0.6360 - val_acc: 0.7656
#
# Epoch 00015: val_acc did not improve from 0.84375
# Epoch 16/100
# 13/13 [==============================] - 7s 531ms/step - loss: 0.1513 - acc: 0.9459 - val_loss: 0.6416 - val_acc: 0.7344
#
# Epoch 00016: val_acc did not improve from 0.84375
# Epoch 17/100
# 13/13 [==============================] - 7s 514ms/step - loss: 0.1464 - acc: 0.9471 - val_loss: 0.5702 - val_acc: 0.8125
#
# Epoch 00017: val_acc did not improve from 0.84375
# Epoch 18/100
# 13/13 [==============================] - 6s 478ms/step - loss: 0.1289 - acc: 0.9555 - val_loss: 0.4730 - val_acc: 0.8281
#
# Epoch 00018: val_acc did not improve from 0.84375
# Epoch 19/100
# ...
# Epoch 13/100
# 13/13 [==============================] - 7s 549ms/step - loss: 0.6930 - acc: 0.5108 - val_loss: 0.6987 - val_acc: 0.3594
#
# Epoch 00013: val_acc did not improve from 0.64062
# Epoch 14/100
# 13/13 [==============================] - 7s 556ms/step - loss: 0.6930 - acc: 0.5108 - val_loss: 0.6975 - val_acc: 0.3594
#
# Epoch 00014: val_acc did not improve from 0.64062
# Epoch 15/100
# 13/13 [==============================] - 8s 579ms/step - loss: 0.6930 - acc: 0.5108 - val_loss: 0.6986 - val_acc: 0.3594
#
# Epoch 00015: val_acc did not improve from 0.64062
# Epoch 16/100
# 13/13 [==============================] - 7s 557ms/step - loss: 0.6930 - acc: 0.5108 - val_loss: 0.6987 - val_acc: 0.3594
#
# Epoch 00016: val_acc did not improve from 0.64062
# Epoch 17/100
# 13/13 [==============================] - 7s 569ms/step - loss: 0.6930 - acc: 0.5108 - val_loss: 0.6984 - val_acc: 0.3594
#
# Epoch 00017: val_acc did not improve from 0.64062
# Epoch 18/100
# 13/13 [==============================] - 7s 545ms/step - loss: 0.6930 - acc: 0.5108 - val_loss: 0.7003 - val_acc: 0.3594
#
# Epoch 00018: val_acc did not improve from 0.64062
# Epoch 19/100
# 13/13 [==============================] - 7s 547ms/step - loss: 0.6931 - acc: 0.5108 - val_loss: 0.6983 - val_acc: 0.3594
#
# Epoch 00019: val_acc did not improve from 0.64062
# Epoch 20/100
# 13/13 [==============================] - 7s 572ms/step - loss: 0.6929 - acc: 0.5108 - val_loss: 0.6998 - val_acc: 0.3594
#
# Epoch 00020: val_acc did not improve from 0.64062
# Epoch 21/100
# 13/13 [==============================] - 7s 573ms/step - loss: 0.6930 - acc: 0.5108 - val_loss: 0.6992 - val_acc: 0.3594
#
# Epoch 00021: val_acc did not improve from 0.64062
# /home/xhh/anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/metrics/classification.py:872: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# --------------------------
#
# AUC: 0.500000
# ACC: 0.472222
# MCC : 0.000000
# TPR:1.000000
# FPR:1.000000
# Pre:0.472222
# F1:0.641509
# --------------------------
#
# Epoch 1/100
# 13/13 [==============================] - 36s 3s/step - loss: 1.0724 - acc: 0.4820 - val_loss: 0.6939 - val_acc: 0.4844
#
# Epoch 00001: val_acc improved from -inf to 0.48438, saving model to CV/node_go_seq2-8.hdf5
# Epoch 2/100
# 13/13 [==============================] - 8s 605ms/step - loss: 0.6867 - acc: 0.5445 - val_loss: 0.6420 - val_acc: 0.6875
#
# Epoch 00002: val_acc improved from 0.48438 to 0.68750, saving model to CV/node_go_seq2-8.hdf5
# Epoch 3/100
# 13/13 [==============================] - 8s 587ms/step - loss: 0.6223 - acc: 0.6767 - val_loss: 0.6983 - val_acc: 0.5469
#
# Epoch 00003: val_acc did not improve from 0.68750
# Epoch 4/100
# 13/13 [==============================] - 7s 538ms/step - loss: 0.5977 - acc: 0.6755 - val_loss: 0.5817 - val_acc: 0.7344
#
# Epoch 00004: val_acc improved from 0.68750 to 0.73438, saving model to CV/node_go_seq2-8.hdf5
# Epoch 5/100
# 13/13 [==============================] - 7s 550ms/step - loss: 0.5234 - acc: 0.7296 - val_loss: 0.6184 - val_acc: 0.6875
#
# Epoch 00005: val_acc did not improve from 0.73438
# Epoch 6/100
# 13/13 [==============================] - 7s 554ms/step - loss: 0.4763 - acc: 0.7776 - val_loss: 0.6352 - val_acc: 0.6875
#
# Epoch 00006: val_acc did not improve from 0.73438
# Epoch 7/100
# 13/13 [==============================] - 7s 561ms/step - loss: 0.4457 - acc: 0.8257 - val_loss: 0.6584 - val_acc: 0.7031
#
# Epoch 00007: val_acc did not improve from 0.73438
# Epoch 8/100
# 13/13 [==============================] - 7s 508ms/step - loss: 0.5294 - acc: 0.7224 - val_loss: 0.5978 - val_acc: 0.6719
#
# Epoch 00008: val_acc did not improve from 0.73438
# Epoch 9/100
# 13/13 [==============================] - 7s 508ms/step - loss: 0.3445 - acc: 0.8486 - val_loss: 0.6590 - val_acc: 0.6875
#
# Epoch 00009: val_acc did not improve from 0.73438
# Epoch 10/100
# 13/13 [==============================] - 7s 533ms/step - loss: 0.3078 - acc: 0.8678 - val_loss: 0.7365 - val_acc: 0.6719
#
# Epoch 00010: val_acc did not improve from 0.73438
# Epoch 11/100
# 13/13 [==============================] - 7s 516ms/step - loss: 0.2116 - acc: 0.9026 - val_loss: 0.5828 - val_acc: 0.7344
#
# Epoch 00011: val_acc did not improve from 0.73438
# Epoch 12/100
# 13/13 [==============================] - 7s 526ms/step - loss: 0.2494 - acc: 0.8978 - val_loss: 0.7690 - val_acc: 0.6406
#
# Epoch 00012: val_acc did not improve from 0.73438
# Epoch 13/100
# 13/13 [==============================] - 7s 504ms/step - loss: 0.2803 - acc: 0.8762 - val_loss: 0.7691 - val_acc: 0.7031
#
# Epoch 00013: val_acc did not improve from 0.73438
# Epoch 14/100
# 13/13 [==============================] - 7s 533ms/step - loss: 0.1943 - acc: 0.9219 - val_loss: 0.7801 - val_acc: 0.6875
#
# Epoch 00014: val_acc did not improve from 0.73438
# Epoch 15/100
# 13/13 [==============================] - 7s 503ms/step - loss: 0.2242 - acc: 0.9111 - val_loss: 1.0225 - val_acc: 0.6875
#
# Epoch 00015: val_acc did not improve from 0.73438
# Epoch 16/100
# 13/13 [==============================] - 7s 508ms/step - loss: 0.2290 - acc: 0.8930 - val_loss: 0.7611 - val_acc: 0.7188
#
# Epoch 00016: val_acc did not improve from 0.73438
# Epoch 17/100
# 13/13 [==============================] - 7s 551ms/step - loss: 0.1130 - acc: 0.9519 - val_loss: 1.2850 - val_acc: 0.7344
#
# Epoch 00017: val_acc did not improve from 0.73438
# Epoch 18/100
# 13/13 [==============================] - 7s 527ms/step - loss: 0.2469 - acc: 0.9183 - val_loss: 0.8180 - val_acc: 0.6562
#
# Epoch 00018: val_acc did not improve from 0.73438
# Epoch 19/100
# 13/13 [==============================] - 7s 566ms/step - loss: 0.2304 - acc: 0.8918 - val_loss: 0.9279 - val_acc: 0.7188
#
# Epoch 00019: val_acc did not improve from 0.73438
# Epoch 20/100
# 13/13 [==============================] - 7s 513ms/step - loss: 0.1845 - acc: 0.9183 - val_loss: 0.9883 - val_acc: 0.6562
#
# Epoch 00020: val_acc did not improve from 0.73438
# Epoch 21/100
# 13/13 [==============================] - 7s 503ms/step - loss: 0.1477 - acc: 0.9435 - val_loss: 0.9698 - val_acc: 0.7188
#
# Epoch 00021: val_acc did not improve from 0.73438
# Epoch 22/100
# 13/13 [==============================] - 7s 537ms/step - loss: 0.0867 - acc: 0.9639 - val_loss: 0.9679 - val_acc: 0.6406
#
# Epoch 00022: val_acc did not improve from 0.73438
# Epoch 23/100
# 13/13 [==============================] - 7s 544ms/step - loss: 0.1151 - acc: 0.9555 - val_loss: 0.9870 - val_acc: 0.7344
#
# Epoch 00023: val_acc did not improve from 0.73438
# Epoch 24/100
# 13/13 [==============================] - 7s 516ms/step - loss: 0.1680 - acc: 0.9351 - val_loss: 1.1822 - val_acc: 0.6406
#
# Epoch 00024: val_acc did not improve from 0.73438
# --------------------------
#
# AUC: 0.922069
# ACC: 0.805556
# MCC : 0.641373
# TPR:0.689655
# FPR:0.060000
# Pre:0.930233
# F1:0.792079
# --------------------------
#
# Epoch 1/100
# 13/13 [==============================] - 43s 3s/step - loss: 1.0002 - acc: 0.4832 - val_loss: 0.6866 - val_acc: 0.5938
#
# Epoch 00001: val_acc improved from -inf to 0.59375, saving model to CV/node_go_seq2-9.hdf5
# Epoch 2/100
# 13/13 [==============================] - 6s 483ms/step - loss: 0.6920 - acc: 0.5853 - val_loss: 0.6963 - val_acc: 0.4844
#
# Epoch 00002: val_acc did not improve from 0.59375
# Epoch 3/100
# 13/13 [==============================] - 6s 469ms/step - loss: 0.6248 - acc: 0.6286 - val_loss: 0.6735 - val_acc: 0.6250
#
# Epoch 00003: val_acc improved from 0.59375 to 0.62500, saving model to CV/node_go_seq2-9.hdf5
# Epoch 4/100
# 13/13 [==============================] - 6s 495ms/step - loss: 0.5829 - acc: 0.7079 - val_loss: 0.8758 - val_acc: 0.4844
#
# Epoch 00004: val_acc did not improve from 0.62500
# Epoch 5/100
# 13/13 [==============================] - 5s 397ms/step - loss: 0.5379 - acc: 0.7272 - val_loss: 0.6479 - val_acc: 0.6406
#
# Epoch 00005: val_acc improved from 0.62500 to 0.64062, saving model to CV/node_go_seq2-9.hdf5
# Epoch 6/100
# 13/13 [==============================] - 5s 389ms/step - loss: 0.5288 - acc: 0.7524 - val_loss: 0.6274 - val_acc: 0.6562
#
# Epoch 00006: val_acc improved from 0.64062 to 0.65625, saving model to CV/node_go_seq2-9.hdf5
# Epoch 7/100
# 13/13 [==============================] - 6s 487ms/step - loss: 0.4377 - acc: 0.8053 - val_loss: 0.8141 - val_acc: 0.6562
#
# Epoch 00007: val_acc did not improve from 0.65625
# Epoch 8/100
# 13/13 [==============================] - 7s 503ms/step - loss: 0.3274 - acc: 0.8594 - val_loss: 0.8176 - val_acc: 0.6562
#
# Epoch 00008: val_acc did not improve from 0.65625
# Epoch 9/100
# 13/13 [==============================] - 6s 487ms/step - loss: 0.3059 - acc: 0.8630 - val_loss: 0.6468 - val_acc: 0.7188
#
# Epoch 00009: val_acc improved from 0.65625 to 0.71875, saving model to CV/node_go_seq2-9.hdf5
# Epoch 10/100
# 13/13 [==============================] - 6s 448ms/step - loss: 0.3076 - acc: 0.8762 - val_loss: 0.7318 - val_acc: 0.7188
#
# Epoch 00010: val_acc did not improve from 0.71875
# Epoch 11/100
# 13/13 [==============================] - 5s 408ms/step - loss: 0.2856 - acc: 0.8774 - val_loss: 0.7660 - val_acc: 0.6406
#
# Epoch 00011: val_acc did not improve from 0.71875
# Epoch 12/100
# 13/13 [==============================] - 5s 411ms/step - loss: 0.2242 - acc: 0.8942 - val_loss: 0.8597 - val_acc: 0.6094
#
# Epoch 00012: val_acc did not improve from 0.71875
# Epoch 13/100
# 13/13 [==============================] - 5s 409ms/step - loss: 0.2039 - acc: 0.9123 - val_loss: 1.0882 - val_acc: 0.6094
#
# Epoch 00013: val_acc did not improve from 0.71875
# Epoch 14/100
# 13/13 [==============================] - 5s 409ms/step - loss: 0.1563 - acc: 0.9399 - val_loss: 1.0665 - val_acc: 0.6875
#
# Epoch 00014: val_acc did not improve from 0.71875
# Epoch 15/100
# 13/13 [==============================] - 5s 416ms/step - loss: 0.1510 - acc: 0.9375 - val_loss: 1.0807 - val_acc: 0.6719
#
# Epoch 00015: val_acc did not improve from 0.71875
# Epoch 16/100
# 13/13 [==============================] - 7s 520ms/step - loss: 0.2702 - acc: 0.9026 - val_loss: 0.8799 - val_acc: 0.7031
#
# Epoch 00016: val_acc did not improve from 0.71875
# Epoch 17/100
# 13/13 [==============================] - 7s 510ms/step - loss: 0.3906 - acc: 0.8161 - val_loss: 0.7503 - val_acc: 0.6875
#
# Epoch 00017: val_acc did not improve from 0.71875
# Epoch 18/100
# 13/13 [==============================] - 7s 512ms/step - loss: 0.1866 - acc: 0.9243 - val_loss: 0.9459 - val_acc: 0.7031
#
# Epoch 00018: val_acc did not improve from 0.71875
# Epoch 19/100
# 13/13 [==============================] - 7s 522ms/step - loss: 0.1380 - acc: 0.9423 - val_loss: 0.9284 - val_acc: 0.6875
#
# Epoch 00019: val_acc did not improve from 0.71875
# Epoch 20/100
# 13/13 [==============================] - 7s 525ms/step - loss: 0.1052 - acc: 0.9555 - val_loss: 1.4162 - val_acc: 0.7031
#
# Epoch 00020: val_acc did not improve from 0.71875
# Epoch 21/100
# 13/13 [==============================] - 7s 528ms/step - loss: 0.1067 - acc: 0.9591 - val_loss: 1.1299 - val_acc: 0.7031
#
# Epoch 00021: val_acc did not improve from 0.71875
# Epoch 22/100
# 13/13 [==============================] - 7s 562ms/step - loss: 0.1303 - acc: 0.9495 - val_loss: 1.2848 - val_acc: 0.7031
#
# Epoch 00022: val_acc did not improve from 0.71875
# Epoch 23/100
# 13/13 [==============================] - 7s 546ms/step - loss: 0.1071 - acc: 0.9651 - val_loss: 1.6693 - val_acc: 0.6562
#
# Epoch 00023: val_acc did not improve from 0.71875
# Epoch 24/100
# 13/13 [==============================] - 7s 522ms/step - loss: 0.1002 - acc: 0.9688 - val_loss: 1.1167 - val_acc: 0.7188
#
# Epoch 00024: val_acc did not improve from 0.71875
# Epoch 25/100
# 13/13 [==============================] - 7s 526ms/step - loss: 0.0866 - acc: 0.9651 - val_loss: 1.4083 - val_acc: 0.6875
#
# Epoch 00025: val_acc did not improve from 0.71875
# Epoch 26/100
# 13/13 [==============================] - 7s 544ms/step - loss: 0.0980 - acc: 0.9603 - val_loss: 1.4391 - val_acc: 0.7500
#
# Epoch 00026: val_acc improved from 0.71875 to 0.75000, saving model to CV/node_go_seq2-9.hdf5
# Epoch 27/100
# 13/13 [==============================] - 7s 539ms/step - loss: 0.0932 - acc: 0.9712 - val_loss: 0.9149 - val_acc: 0.7656
#
# Epoch 00027: val_acc improved from 0.75000 to 0.76562, saving model to CV/node_go_seq2-9.hdf5
# Epoch 28/100
# 13/13 [==============================] - 7s 510ms/step - loss: 0.0887 - acc: 0.9543 - val_loss: 1.8781 - val_acc: 0.7188
#
# Epoch 00028: val_acc did not improve from 0.76562
# Epoch 29/100
# 13/13 [==============================] - 7s 532ms/step - loss: 0.0581 - acc: 0.9784 - val_loss: 1.6528 - val_acc: 0.7500
#
# Epoch 00029: val_acc did not improve from 0.76562
# Epoch 30/100
# 13/13 [==============================] - 7s 517ms/step - loss: 0.0628 - acc: 0.9784 - val_loss: 1.5400 - val_acc: 0.6875
#
# Epoch 00030: val_acc did not improve from 0.76562
# Epoch 31/100
# 13/13 [==============================] - 7s 569ms/step - loss: 0.0719 - acc: 0.9748 - val_loss: 1.1717 - val_acc: 0.7031
#
# Epoch 00031: val_acc did not improve from 0.76562
# Epoch 32/100
# 13/13 [==============================] - 8s 605ms/step - loss: 0.0889 - acc: 0.9688 - val_loss: 0.9570 - val_acc: 0.7188
#
# Epoch 00032: val_acc did not improve from 0.76562
# Epoch 33/100
# 13/13 [==============================] - 7s 573ms/step - loss: 0.0666 - acc: 0.9760 - val_loss: 1.3007 - val_acc: 0.7031
#
# Epoch 00033: val_acc did not improve from 0.76562
# Epoch 34/100
# 13/13 [==============================] - 8s 600ms/step - loss: 0.0762 - acc: 0.9760 - val_loss: 1.2767 - val_acc: 0.7344
#
# Epoch 00034: val_acc did not improve from 0.76562
# Epoch 35/100
# 13/13 [==============================] - 7s 567ms/step - loss: 0.0263 - acc: 0.9928 - val_loss: 1.5267 - val_acc: 0.6875
#
# Epoch 00035: val_acc did not improve from 0.76562
# Epoch 36/100
# 13/13 [==============================] - 7s 573ms/step - loss: 0.0672 - acc: 0.9724 - val_loss: 2.6328 - val_acc: 0.6094
#
# Epoch 00036: val_acc did not improve from 0.76562
# Epoch 37/100
# 13/13 [==============================] - 8s 599ms/step - loss: 0.1740 - acc: 0.9351 - val_loss: 1.0398 - val_acc: 0.7031
#
# Epoch 00037: val_acc did not improve from 0.76562
# Epoch 38/100
# 13/13 [==============================] - 8s 591ms/step - loss: 0.1361 - acc: 0.9519 - val_loss: 1.6599 - val_acc: 0.7188
#
# Epoch 00038: val_acc did not improve from 0.76562
# Epoch 39/100
# 13/13 [==============================] - 7s 577ms/step - loss: 0.1129 - acc: 0.9567 - val_loss: 1.1985 - val_acc: 0.7500
#
# Epoch 00039: val_acc did not improve from 0.76562
# Epoch 40/100
# 13/13 [==============================] - 7s 576ms/step - loss: 0.0717 - acc: 0.9736 - val_loss: 1.3598 - val_acc: 0.7344
#
# Epoch 00040: val_acc did not improve from 0.76562
# Epoch 41/100
# 13/13 [==============================] - 8s 603ms/step - loss: 0.1325 - acc: 0.9507 - val_loss: 1.2002 - val_acc: 0.6719
#
# Epoch 00041: val_acc did not improve from 0.76562
# Epoch 42/100
# 13/13 [==============================] - 8s 590ms/step - loss: 0.0711 - acc: 0.9772 - val_loss: 1.7476 - val_acc: 0.6875
#
# Epoch 00042: val_acc did not improve from 0.76562
# Epoch 43/100
# 13/13 [==============================] - 8s 593ms/step - loss: 0.0397 - acc: 0.9856 - val_loss: 1.5929 - val_acc: 0.6719
#
# Epoch 00043: val_acc did not improve from 0.76562
# Epoch 44/100
# 13/13 [==============================] - 8s 592ms/step - loss: 0.0836 - acc: 0.9688 - val_loss: 1.3938 - val_acc: 0.6406
#
# Epoch 00044: val_acc did not improve from 0.76562
# Epoch 45/100
# 13/13 [==============================] - 8s 600ms/step - loss: 0.0542 - acc: 0.9808 - val_loss: 1.6180 - val_acc: 0.6875
#
# Epoch 00045: val_acc did not improve from 0.76562
# Epoch 46/100
# 13/13 [==============================] - 8s 590ms/step - loss: 0.0240 - acc: 0.9892 - val_loss: 1.7967 - val_acc: 0.7344
#
# Epoch 00046: val_acc did not improve from 0.76562
# Epoch 47/100
# 13/13 [==============================] - 8s 595ms/step - loss: 0.0432 - acc: 0.9832 - val_loss: 2.0806 - val_acc: 0.7031
#
# Epoch 00047: val_acc did not improve from 0.76562
# --------------------------
#
# AUC: 0.935821
# ACC: 0.870370
# MCC : 0.737254
# TPR:0.787234
# FPR:0.065574
# Pre:0.902439
# F1:0.840909
# --------------------------
#
# mean AUC: 0.911644
# mean ACC: 0.849242
# mean MCC : 0.709353
# mean TPR:0.870158
# mean FPR:0.162667
# mean Pre:0.879150
# mean F1:0.860697

# %%
import numpy as np 
results1 =   np.load( 'node2vec_go_seq0.npz')
results2 =   np.load( 'node2vec_go_seq1.npz')
results3 =   np.load( 'node2vec_go_seq2.npz')
print ('mean AUC: %f' %  ( (np.mean( results1[ 'AUCs' ] )  + np.mean(  results2[ 'AUCs' ] )  + np.mean(results3[ 'AUCs' ]))/3     ) )
print ('mean ACC: %f' %   ( (np.mean( results1[ 'ACCs' ] )  + np.mean(  results2[ 'ACCs' ] )  + np.mean(results3[ 'ACCs' ]))/3) )
print ('mean MCC : %f' %  (  (np.mean( results1[ 'MCCs' ] )  + np.mean(  results2[ 'MCCs' ] )  + np.mean(results3[ 'MCCs' ])     )/3))
print('mean TPR:%f'%    ((np.mean( results1[ 'TPRs' ] )  + np.mean(  results2[ 'TPRs' ] )  + np.mean(results3[ 'TPRs' ])     )/3))
print('mean FPR:%f'%   ( (np.mean( results1[ 'FPRs' ] )  + np.mean(  results2[ 'FPRs' ] )  + np.mean(results3[ 'FPRs' ])     )/3))
print('mean Pre:%f'%    ((np.mean( results1[ 'Precs' ] )  + np.mean(  results2[ 'Precs' ] )  + np.mean(results3[ 'Precs' ])     )/3))
print('mean F1:%f'%    ((np.mean( results1[ 'F1s' ] )  + np.mean(  results2[ 'F1s' ] )  + np.mean(results3[ 'F1s' ])     )/3))
# Out:
# mean AUC: 0.906283
# mean ACC: 0.841498
# mean MCC : 0.688606
# mean TPR:0.829777
# mean FPR:0.148819
# mean Pre:0.867075
# mean F1:0.838586
